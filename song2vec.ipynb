# %%
import json
import urllib.parse
import re
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from collections import Counter
from gensim.models import Word2Vec
import math
import numpy as np
from sklearn.manifold import TSNE

# %%
with open("data/tracks.idomaar", "r") as tracks:
    trackInfos = tracks.readlines()

with open("data/albums.idomaar", "r") as albums:
    albumInfo = albums.readlines()

with open("data/persons.idomaar", "r") as persons:
    personInfo = persons.readlines()

with open("data/playlist.idomaar", "r") as playlists:
    playlistInfo = playlists.readlines()

with open("data/tags.idomaar", "r") as tags:
    tagInfo = tags.readlines()

with open("data/users.idomaar", "r") as users:
    userInfo = users.readlines()

d = {
    "trackInfo": trackInfos[:10],
    "albumInfo": albumInfo[:10],
    "personInfo": personInfo[:10],
    "playlistInfo": playlistInfo[:10],
    "tagInfo": tagInfo[:10],
    "userInfo": userInfo[:10]
}

var = "trackInfo"
name = var.upper()
data = d[var]
print(name)
for info in data:
    print(info, end="")
# Out:
# TRACKINFO
# track	0	-1	{"duration":-1,"playcount":4,"MBID":null,"name":"000003+Music+Instructor/_/Dj%27s+Rock+Da+House+%C3%82%E2%89%88%C3%86%E2%89%88%C3%8A01+-+Dj+Max-Pulemet+Vs.+Bomfunk+Mc%27s+-+Electro+Breakdance+party+1+%5B2000%5D+=+CD+ONE%C3%82%E2%89%88%C3%86%E2%89%88%C3%8A"}	{"artists":[{"type":"person","id":0}],"albums":[],"tags":[]}
# track	1	-1	{"duration":-1,"playcount":495,"MBID":null,"name":"00-01/_/%D0%A2%D0%B5%D0%BA%D1%81%D1%82"}	{"artists":[{"type":"person","id":1}],"albums":[],"tags":[]}
# track	2	-1	{"duration":-1,"playcount":2,"MBID":null,"name":"0005.+Overkill/_/Overkill"}	{"artists":[{"type":"person","id":2}],"albums":[],"tags":[]}
# track	3	-1	{"duration":-1,"playcount":2,"MBID":null,"name":"000C+Tony+Dize/_/Ruleta+Rusa"}	{"artists":[{"type":"person","id":3}],"albums":[],"tags":[]}
# track	4	-1	{"duration":-1,"playcount":1,"MBID":null,"name":"000+Oscarcito/_/Tumbay%E2%80%9A+(Lyrics)"}	{"artists":[{"type":"person","id":4}],"albums":[],"tags":[]}
# track	5	-1	{"duration":-1,"playcount":16,"MBID":null,"name":"000/_/Rats+and+Butterflies+(Original+Mix)"}	{"artists":[{"type":"person","id":5}],"albums":[],"tags":[]}
# track	6	-1	{"duration":-1,"playcount":34,"MBID":null,"name":"0+0+0/_/Verticle"}	{"artists":[{"type":"person","id":6}],"albums":[],"tags":[]}
# track	7	-1	{"duration":-1,"playcount":163,"MBID":null,"name":"000/_/Verticle"}	{"artists":[{"type":"person","id":5}],"albums":[],"tags":[]}
# track	8	-1	{"duration":269000,"playcount":163,"MBID":"bba8bc34-850d-4b40-996a-13b769c190a0","name":"0010110000010011+(Cancer)/_/Naonian+Style"}	{"artists":[{"type":"person","id":7}],"albums":[{"type":"album","id":0}],"tags":[{"type":"tag","id":170251},{"type":"tag","id":257861},{"type":"tag","id":120463}]}
# track	9	-1	{"duration":-1,"playcount":12,"MBID":null,"name":"001/_/03_Respublika"}	{"artists":[{"type":"person","id":8}],"albums":[],"tags":[]}

# %%
idToArtistSong = {}
for trackInfo in trackInfos:
    trackId = str(trackInfo.split("\t")[1])
    jsonTrack = trackInfo.split("\t")[3]
    trackUrl = json.loads(jsonTrack)
    trackName = trackUrl["name"]
    artistSongInfo = trackName.split("/_/")
    artist = urllib.parse.unquote_plus(artistSongInfo[0])
    song = urllib.parse.unquote_plus(artistSongInfo[1])
    artist_song = artist.lower() + "__" + song.lower()
    artist_song = re.sub(r'[^\w\s\-\'\_]', '', artist_song)
    
    idToArtistSong[trackId] = artist_song

# %%
for k, v in list(idToArtistSong.items())[:21]:
    print(k, v)
# Out:
# 0 000003 music instructor__dj's rock da house âæê01 - dj max-pulemet vs bomfunk mc's - electro breakdance party 1 2000  cd oneâæê
# 1 00-01__текст
# 2 0005 overkill__overkill
# 3 000c tony dize__ruleta rusa
# 4 000 oscarcito__tumbay lyrics
# 5 000__rats and butterflies original mix
# 6 0 0 0__verticle
# 7 000__verticle
# 8 0010110000010011 cancer__naonian style
# 9 001__03_respublika
# 10 001al fatehah  pembukaan__001al fatehah  pembukaan
# 11 001 amber gomez__i'm not black and blue
# 12 001_ariya__rabstvo illyuziy
# 13 001 dimitri vegas like mike gta__turn it up feat wolfpack original mix
# 14 001_hotel__califo
# 15 002__02_volna
# 16 002__09_ot jenchin krugom golova
# 17 002_ariya__nebo tebya naydet
# 18 002_ariya__raskachaem etot mir
# 19 002__boys don't cry - the cure

# %%
type(idToArtistSong)
# Out:
# dict

# %%
with open("data/playlist.idomaar", "r") as playlists:
    playlistInfo = playlists.readlines()

convertedPlayLists = []
for playlist in playlistInfo:
    userAndTrackList = playlist.split("\t")[4]
    trackDict = json.loads(userAndTrackList)
    trackList = trackDict["objects"]
    elemOfPlayList = []
    if len(trackList) == 0 or len(trackList[0]) == 0:
        continue

    for trackElem in trackList:
        artist_song = idToArtistSong[str(trackElem["id"])]
        elemOfPlayList.append(artist_song)
    convertedPlayLists.append(elemOfPlayList)

# %%
convertedPlayLists
# Out:
# [['the whip__trash crookers remix',
#   'modeselektor__sucker pin',
#   'simian mobile disco__hustler',
#   'gossip__standing in the way of control',
#   'kalwi  remi__explosion dj theo remix',
#   'jackson and his computer band__arpeggio',
#   'midnight juggernauts__into the galaxy',
#   "klaxons__it's not over yet",
#   'yeah yeah yeahs__maps',
#   'radiohead__true love waits live',
#   'queens of the stone age__make it wit chu',
#   'queens of the stone age__feel good hit of the summer',
#   "beastie boys__i don't know",
#   'the rakes__the world was a mess but his hair was perfect',
#   'foo fighters__my hero',
#   "weezer__say it ain't so original album mix",
#   'radiohead__bangers',
#   'the strokes__take it or leave it',
#   'jamie t__salvador',
#   'arcade fire__intervention',
#   'harrisons__dear constable',
#   'milburn__what will you do when the money goes',
#   'she__why do you let me stay here',
#   'the black keys__strange times',
#   'the raconteurs__salute your solution',
#   'the futureheads__radio heart',
#   'vampire weekend__campus'],
#  ['the bloody beetroots__butter',
#   'the bloody beetroots__cornelius radio oi',
#   'erol alkan__death suite',
#   'gtronic__iron man',
#   'dapayk__island feat caro noze rmx',
#   'the presets__talk like that',
#   "simian mobile disco__10000 horses can't be wrong",
#   'don rimini__rave on',
#   'don rimini__ohow'],
#  ['portugal the man__1989',
#   'the wedding present__kennedy',
#   'the pogues__misty morning albert bridge',
#   "the weakerthans__time's arrow",
#   'the cure__lullaby',
#   'the sugarcubes__regina',
#   'happy mondays__wfl',
#   'james__sit down',
#   'pixies__monkey gone to heaven',
#   'the lemonheads__luka',
#   'the lightning seeds__pure',
#   'inspiral carpets__move',
#   'rem__orange crush',
#   'violent femmes__nightmares',
#   'morrissey__the last of the famous international playboys',
#   'the rakes__1989'],
#  ['rem__man on the moon',
#   'mercury rev__tides of the moon',
#   'anna ternheim__fly me to the moon',
#   'yo la tengo__moonrock mambo',
#   'feist__my moon my man',
#   'herman düne__by the light of the moon',
#   'the doors__moonlight drive',
#   'cat power__the moon',
#   'sambassadeur__new moon',
#   'zz top__she loves my automobile',
#   '__must be the moon',
#   'the field mice__missing the moon',
#   'polarkreis 18__under this big moon',
#   'shivaree__goodnight moon',
#   'sunset rubdown__silver moons'],
#  ['los campesinos__we throw parties you throw knives',
#   "the organ__we've got to meet",
#   'los campesinos__you me dancing',
#   'shout out louds__tonight i have to leave it',
#   'stars__take me to the riot',
#   'belle and sebastian__the stars of track and field',
#   'zz top__she loves my automobile',
#   'the sounds__painted by numbers',
#   'edson__sunday lovely sunday',
#   "belle and sebastian__get me away from here i'm dying",
#   'get well soon__if this hat is missing i have gone hunting',
#   'james__born of frustration',
#   "james__she's a star",
#   'arctic monkeys__if you were there beware',
#   'broder daniel__shoreline',
#   'pelle carlberg__middleclass kid',
#   'the shins__saint simon',
#   'arctic monkeys__fluorescent adolescent',
#   'belle and sebastian__the state i am in',
#   'shout out louds__impossible',
#   'babyshambles__sedative',
#   'loney dear__saturday waits',
#   'the indelicates__we hate the kids',
#   'loney dear__i am john',
#   'anna ternheim__to be gone',
#   'belle and sebastian__like dylan in the movies',
#   'the indelicates__new art for the people',
#   'malcolm middleton__fight like the night',
#   'galaxie 500__blue thunder',
#   'the view__wasted little djs',
#   'violent femmes__add it up',
#   'violent femmes__gone daddy gone',
#   'violent femmes__blister in the sun',
#   "the indelicates__the last significant statement to be made in rock'n'roll",
#   'the indelicates__heroin',
#   'editors__an end has a start',
#   'tokyo police club__nature of the experiment',
#   'malajube__montréal -40c',
#   'stars__the night starts here',
#   'arcade fire__intervention',
#   'voxtrot__your biggest fan',
#   'the lodger__you got me wrong',
#   'the organ__memorize the city',
#   'los campesinos__death to los campesinos',
#   'lucky soul__the great unwanted',
#   'los campesinos__it started with a mixx',
#   'pelle carlberg__clever girls like clever boys much more than clever boys like clever girls',
#   'los campesinos__frontwards',
#   'seidenmatt__bergen',
#   'the organ__brother',
#   'the thermals__a stare like yours',
#   'kaiser chiefs__ruby',
#   'editors__munich',
#   'editors__all sparks',
#   'klee__liebe mich leben',
#   'klee__gold',
#   'anajo__wenn du nur wüsstest',
#   'klee__tausendfach',
#   'wir sind helden__wenn es passiert',
#   'wir sind helden__nur ein wort',
#   'the concretes__chosen one',
#   'locas in love__zum beispiel ein unfall',
#   'wolke__wir werden immer jünger',
#   'battle__wicked owl',
#   'tokyo police club__citizens of tomorrow',
#   'stars__ageless beauty',
#   'battle__isabelle',
#   'good shoes__in the city',
#   'the thermals__a pillar of salt',
#   'the thermals__an ear for baby',
#   'kaiser chiefs__everyday i love you less and less',
#   'operator please__leave it alone',
#   'operator please__just a song about ping pong',
#   'operator please__two for my seconds',
#   'operator please__get what you want',
#   'operator please__crash tragic',
#   'zz top__she loves my automobile',
#   'zz top__she loves my automobile',
#   'stars__your ex-lover is dead',
#   'zz top__she loves my automobile',
#   "immaculate machine__c'mon sea legs",
#   'broder daniel__abc 123',
#   'lars winnerbäck__elegi',
#   'pavement__frontwards'],
#  ['immaculate machine__broken ship',
#   'the organ__brother',
#   "the organ__it's time to go",
#   "the organ__we've got to meet",
#   'the organ__steven smith',
#   'the organ__love love love',
#   'the organ__fire in the ocean',
#   'immaculate machine__jarhand',
#   'immaculate machine__dear confessor',
#   "immaculate machine__c'mon sea legs",
#   'immaculate machine__no such thing as the future',
#   'immaculate machine__no way out',
#   'stars__your ex-lover is dead',
#   'stars__take me to the riot',
#   'stars__ageless beauty',
#   'stars__the night starts here',
#   'stars__reunion',
#   'pony up__the truth about cats and dogs is that they die',
#   'zz top__she loves my automobile',
#   'zz top__she loves my automobile',
#   'tegan and sara__walking with a ghost',
#   "tegan and sara__you wouldn't like me",
#   'tegan and sara__the con',
#   'tokyo police club__nature of the experiment',
#   'tokyo police club__your english is good',
#   'tokyo police club__tessellate',
#   'tokyo police club__la ferrassie',
#   'tokyo police club__cheer it on',
#   'malajube__pâte filo',
#   'malajube__montréal -40c',
#   'the hidden cameras__learning the lie',
#   'the hidden cameras__awoo'],
#  ['joanna newsom__the book of right-on',
#   '石井妥師__fabricated background',
#   '石井妥師__ibcj siege rope',
#   'dj shadow__blood on the motorway',
#   'dj shadow__meets his maker',
#   'amon tobin__slowly',
#   'amon tobin__keep your distance',
#   'boards of canada__music is math',
#   "the decemberists__the island come and see the landlord's daughter you'll not feel the drowning",
#   'modest mouse__float on',
#   'massive attack__safe from harm',
#   'yes__close to the edge',
#   'yes__and you and i',
#   'massive attack__unfinished sympathy',
#   'tricky__hell is round the corner',
#   'portishead__roads',
#   'lamb__gorecki',
#   'morcheeba__the sea',
#   'cat power__empty shell',
#   'camille__au port',
#   'cocorosie__terrible angels',
#   'grizzly bear__on a neck on a spit',
#   'jethro tull__aqualung',
#   'supertramp__take the long way home',
#   'sufjan stevens__to be alone with you',
#   'ane brun__on off',
#   'ane brun__shot my heart',
#   'martina topley-bird__need one',
#   'element of crime__weit ist der weg',
#   'element of crime__weil du nicht da bist',
#   'black rebel motorcycle club__shuffle your feet',
#   'caribou__pelican narrows',
#   'beirut__brandenburg',
#   'badly drawn boy__say it again',
#   'smog__rock bottom riser',
#   'smog__in the pines',
#   'dj shadow__fixed income',
#   'dj shadow__stemlong stem',
#   'dj shadow__what does your soul look like part 4',
#   'feist__when i was a young girl',
#   'feist__lonely lonely',
#   'lisa germano__from a shell',
#   'boards of canada__dayvan cowboy',
#   'portishead__revenge of the number'],
#  ['bent__as you fall',
#   'element of crime__es regnet',
#   'element of crime__wenn der morgen graut',
#   'lizz wright__thank you',
#   'portishead__revenge of the number',
#   'franz schubert__impromptu no 3 in g flat major',
#   'serge gainsbourg__en melody',
#   'lisa ekdahl__vem vet',
#   'bonobo__hammond pops',
#   'émilie simon__to the dancers on the ice',
#   'arto lindsay__ridiculously deep',
#   'sanseverino__mal ô mains',
#   'jeff buckley__everybody here wants you',
#   'joan as police woman__magpies',
#   'boards of canada__aquarius',
#   'bruce springsteen__shenandoah',
#   'blossom dearie__try your wings',
#   'sarah vaughan__summertime',
#   'jamie lidell__game for fools',
#   'billy nicholls__daytime girl coda',
#   'piano magic__wrong french',
#   'jim noir__my patch',
#   'duke ellington__black and tan fantasy',
#   'prince buster__madness',
#   'yes__the remembering high the memory',
#   'quantic__the 5th exotic',
#   'joni mitchell__i think i understand',
#   'boom bip__roads must roll',
#   'nick drake__way to blue',
#   'télépopmusik__breathe',
#   "ken boothe__is it because i'm black",
#   'faithless__no roots',
#   'beth gibbons__mysteries',
#   'blockhead__expiration date',
#   'esthero__anywayz',
#   'the velvet underground__beginning to see the light',
#   'duman__yürekten',
#   'kid koala__basin street blues',
#   'nathan haines__squire for hire',
#   'two lone swordsmen__taste of our flames',
#   'nas__represent',
#   'charles mingus__devil woman',
#   "the beta band__it's not too beautiful",
#   'willy mason__all you can do',
#   'kings of convenience__winning a battle losing the war',
#   'the fiery furnaces__whistle rhapsody',
#   'super furry animals__alternate route to vulcan street',
#   'bang gang__follow',
#   'lhasa__de cara a la pared',
#   "moondog__bird's lament",
#   'rodrigo leão__pasión',
#   "aim__ain't got time to waste feat yz",
#   'sage francis__makeshift patriot',
#   'portishead__theme from to kill a dead man',
#   "nina simone__you'll never walk alone",
#   'barry adamson__jazz devil',
#   'yes__starship trooper',
#   'tricky__hell is around the corner',
#   'ane brun__shot my heart',
#   'archive__last five',
#   'imelda may__knock 123',
#   'dominic miller__do you want me',
#   'beastie boys__freaky hijiki',
#   'ween__take me away',
#   'gabriel fauré__pavane op 50',
#   'zz top__she loves my automobile',
#   'gorillaz__hong kong',
#   'chico buarque__valsinha',
#   'arthur h__adieu tristesse'],
#  ['demon__happy therapy lifelike remix',
#   'way out west__killa',
#   'the chemical brothers__burst generator',
#   'justice__dance',
#   'pryda__rymd',
#   'zero 7__destiny',
#   'london elektricity__the mustard song',
#   'london elektricity__vapour trails',
#   'air__all i need',
#   'gabriel__serendipity',
#   'way out west__absinthe dreams',
#   "daft punk__rollin'",
#   'ryukyu underground__mo ashibi jason bentley remix',
#   'aphex twin__windowlicker',
#   'the mfa__overhang',
#   'way out west__apollo',
#   'sonorous__protonic ronski speed mix',
#   'extrawelt__soopertrack',
#   'kyau vs albert__falling anywhere rework',
#   'london elektricity__pussy galore',
#   'zero 7__somersault',
#   'way out west__ub devoid',
#   'the mfa__rinse time',
#   'daft punk__technologic vitalic remix',
#   'zero 7__simple things',
#   'way out west__activity',
#   "tilt__the world doesn't know"],
#  ['kamaya painters__wasteland',
#   'kamaya painters__endless wave albion remix',
#   'solar stone__day by day solar stone dub',
#   'above__alone tonight',
#   'above__no one on earth gabriel',
#   'above__air for life with andy moor',
#   'kyau vs albert__kiksu original mix',
#   'kyau vs albert__falling anywhere rework',
#   'kyau vs albert__are you fine original mix',
#   'gabriel__serendipity',
#   'alex stealthy__something is wrong',
#   'jaytech__spacelift',
#   'way out west__killa',
#   'way out west__apollo',
#   'way out west__fear',
#   'way out west__activity',
#   'way out west__stealth',
#   'way out west__absinthe dreams',
#   'way out west__ub devoid',
#   'way out west__call me',
#   'zz top__she loves my automobile',
#   'paul van dyk__for an angel',
#   'paul van dyk__we are alive',
#   'paul van dyk__nothing but you',
#   'paul van dyk__crush',
#   'paul van dyk__sabotage',
#   'paul van dyk__connected',
#   'paul van dyk__tell me why the riddle',
#   'paul van dyk__get back feat ashley tomberlin',
#   'paul van dyk__reflections',
#   'paul van dyk__buenaventura',
#   'paul van dyk__words',
#   'paul van dyk__beautiful place',
#   'paul van dyk__spellbound',
#   'paul oakenfold__ready steady go',
#   'paul oakenfold__hypnotised',
#   "paul oakenfold__nixon's spirit",
#   'paul oakenfold__motion',
#   'paul oakenfold__the harder they come',
#   'hybrid__finished symphony',
#   'orbital__halcyon 2b on 2b on',
#   'orbital__illuminate',
#   'orbital__belfast',
#   'the future sound of london__papua new guinea',
#   'aphex twin__windowlicker',
#   'aphex twin__avril 14th',
#   'air__all i need',
#   'air__sexy boy',
#   'air__kelly watch the stars',
#   'zero 7__destiny',
#   'zero 7__polaris',
#   'zero 7__give it away',
#   'zero 7__home',
#   'zero 7__simple things',
#   'thievery corporation__lebanese blonde',
#   'röyksopp__eple',
#   'röyksopp__so easy',
#   'the chemical brothers__hey boy hey girl',
#   "the chemical brothers__block rockin' beats",
#   'the chemical brothers__star guitar',
#   'the chemical brothers__the test',
#   'the chemical brothers__come with us',
#   'the chemical brothers__it began in afrika',
#   "groove armada__superstylin'",
#   'groove armada__easy',
#   'the prodigy__smack my bitch up',
#   'the prodigy__breathe',
#   'the prodigy__voodoo people',
#   'the prodigy__funky shit',
#   'the prodigy__no good start the dance',
#   'the prodigy__poison',
#   'the prodigy__out of space',
#   'the prodigy__one love',
#   'the prodigy__voodoo people pendulum remix',
#   'daft punk__da funk',
#   'daft punk__revolution 909',
#   'daft punk__fresh',
#   "daft punk__rollin'",
#   "daft punk__burnin'",
#   'daft punk__technologic vitalic remix',
#   'justice__phantom',
#   'justice__genesis',
#   'london elektricity__pussy galore',
#   'london elektricity__the mustard song',
#   'pendulum__hold your colour',
#   'pendulum__still grey',
#   'pendulum__tarantula',
#   'dj fresh__the immortal',
#   'extrawelt__soopertrack'],
#  ['pink floyd__hey you', "pink floyd__don't leave me now"],
#  ['godspeed you black emperor__moya',
#   'godspeed you black emperor__storm',
#   'mono__burial at sea',
#   'this will destroy you__quiet',
#   'yndi halda__dash and blast',
#   'a silver mt zion__take these hands and throw them in the river',
#   'and so i watch you from afar__set guitars to kill'],
#  ['bohren  der club of gore__prowler',
#   'shakti__mind ecology',
#   'sigur rós__hoppípolla',
#   'claude debussy__clair de lune',
#   'balmorhea__baleen morning'],
#  ['rush__cygnus x-1',
#   'jethro tull__heavy horses',
#   'camel__rhayader',
#   'renaissance__the vultures fly high',
#   'moon safari__bluebells',
#   'birds and buildings__birds flying into buildings',
#   "aphrodite's child__the four horsemen",
#   'the alan parsons project__the raven',
#   'pink floyd__pigs three different ones',
#   'emerson lake__karn evil 9',
#   'king crimson__21st century schizoid man'],
#  ['kings of leon__cold desert',
#   'the spill canvas__sunsets and car crashes',
#   'bruce springsteen__paradise',
#   'gisbert zu knyphausen__der tödliche schlag'],
#  ["city and colour__comin' home",
#   'clickclickdecker__sozialer brennpunkt ich',
#   'thomas d__vergiftet im schlaf',
#   'moby__extreme ways',
#   'enya__my my time flies',
#   'imogen heap__the moment i said it',
#   'bloc party__biko'],
#  ['of montreal__rapture rapes the muses',
#   "lesbians on ecstasy__party time a womyn's luv",
#   'skunk anansie__intellectualise my blackness',
#   "skunk anansie__yes it's fucking political",
#   'the dresden dolls__missed me',
#   'daft punk__one more time richard murder remix',
#   'camera obscura__books wrtten for girls live acoustic version - sunsets',
#   'the cardigans__carnival',
#   'the cardigans__sabbath bloody sabbath',
#   'the cardigans__celia inside',
#   "the cardigans__daddy's car",
#   'the horrors__she is the new thing',
#   'good shoes__all in my head',
#   'good shoes__never meant to hurt you',
#   'good shoes__we are not the same',
#   'good shoes__morden',
#   'the maccabees__smoker',
#   'the maccabees__enabler',
#   'the maccabees__sore throat',
#   'the rakes__22 grand job',
#   'the rakes__strasbourg',
#   'the rakes__retreat',
#   'the rakes__open book',
#   'mumm-ra__the sick deal',
#   'the long blondes__autonomy boy',
#   'dirty on purpose__your summer dress',
#   'the boxer rebellion__watermelon',
#   'the boxer rebellion__the new heavy',
#   'the boxer rebellion__flight',
#   'the pipettes__judy',
#   'the pipettes__why did you stay',
#   "the pipettes__a winter's sky",
#   'kubichek__nightjoy',
#   'kubichek__taxi',
#   'kubichek__roman is better',
#   'voxtrot__mothers sisters daughters',
#   'voxtrot__the start of something',
#   'film school__ps',
#   'film school__ms connection',
#   'of montreal__disconnect the dots',
#   'stars__your ex-lover is dead',
#   'stars__ageless beauty',
#   'the duke spirit__every cell can tell',
#   'field music__a house is not a home',
#   'field music__in context',
#   'field music__sit tight',
#   'field music__tell me keep me',
#   'grandaddy__skateboarding saves me twice',
#   'grandaddy__rear view mirror',
#   'grandaddy__the animal world',
#   "grandaddy__where i'm anymore",
#   "the go team__everyone's a vip to someone",
#   'yo la tengo__detouring america with horns',
#   'peter bjorn and john__it beats me every time',
#   'the damned__neat neat neat',
#   'the damned__shadow to fall',
#   'battle__demons',
#   'battle__wicked owl',
#   'battle__isabelle',
#   'zz top__she loves my automobile',
#   'duels__the slow build',
#   'duels__what we did wrong',
#   'duels__brothers',
#   'elbow__forget myself',
#   'elbow__station approach',
#   'elbow__fugitive motel',
#   'elbow__the stops',
#   "the electric soft parade__if that's the case then i don't know",
#   'the electric soft parade__cold world',
#   'the electric soft parade__life in the backseat',
#   'the electric soft parade__misunderstanding',
#   'built to spill__lie for a lie',
#   'built to spill__revolution',
#   'new young pony club__hiding on the staircase',
#   'jamie t__if you got the money',
#   'jamie t__salvador',
#   'kavinsky__testarossa autodrive',
#   'kavinsky__dead cruiser',
#   'crystal castles__trash hologram',
#   'metric__empty',
#   'metric__grow up and blow away',
#   'metric__the twist',
#   'metric__soft rock star',
#   'lisa loeb__jingle bells',
#   'natasha bedingfield__soulmate',
#   'acid house kings__this heart is a stone',
#   'acid house kings__sunday morning',
#   'acid house kings__say yes if you love me',
#   'acid house kings__do what you wanna do',
#   'broken social scene__love and mathematics',
#   'pink__fame',
#   'saturday looks good to me__lift me up',
#   'saturday looks good to me__disaster',
#   'suburban kids with biblical names__loop duplicate my heart',
#   'suburban kids with biblical names__seems to be on my mind',
#   'the decemberists__oceanside',
#   "the decemberists__i don't mind",
#   'yo la tengo__upside-down',
#   'sambassadeur__between the lines',
#   'sambassadeur__new moon',
#   'sambassadeur__subtle changes',
#   'club 8__whatever you want',
#   "club 8__we're simple minds",
#   'club 8__spring came rain fell',
#   'the legends__play it for today',
#   'the legends__lucky star',
#   'the legends__he knows the sun',
#   'the legends__call it ours',
#   'loveninjas__i wanna be like johnny c',
#   'loveninjas__keep your love',
#   'melissa ferrick__closer',
#   'ingrid michaelson__keep breathing',
#   "brett dennen__ain't no reason",
#   "dar williams__the baby sitter's here",
#   'cat power__the greatest',
#   'andrew bird__the trees were mistaken',
#   'rosie thomas__the one i love',
#   'rosie thomas__much farther to go',
#   'rosie thomas__kite song',
#   'king creosote__homeboy',
#   'catie curtis__troubled mind',
#   'catie curtis__dandelion',
#   'chris pureka__come back home full length version',
#   'zz top__she loves my automobile',
#   'ani difranco__paradigm',
#   'my brightest diamond__something of an end',
#   "el perro del mar__it's all good",
#   'devendra banhart__noah',
#   'devendra banhart__michigan state',
#   'm ward__o lazy days',
#   'micah p hinson__jackeyed',
#   'micah p hinson__the leading guy',
#   'okkervil river__no key no plan',
#   'tunng__bullets',
#   'tunng__soup',
#   'the donnas__are you gonna move it for me',
#   'the long blondes__new idols',
#   'au revoir simone__back in time',
#   'josh ritter__thin blue flame',
#   'josh ritter__good man',
#   'suburban kids with biblical names__rent a wreck',
#   'suburban kids with biblical names__funeral face',
#   'jens lekman__the opposite of hallelujah',
#   'editors__an end has a start',
#   "does it offend you yeah__let's make out",
#   'does it offend you yeah__battle royale',
#   'does it offend you yeah__doomed now',
#   'cazals__a big mistake',
#   'beans on toast__braintree',
#   'good shoes__nazanin',
#   'late of the pier__bathroom gurgle'],
#  ['kill hannah__unwanted'],
#  ['zz top__she loves my automobile',
#   'kingdom__throne',
#   'aesop rock__abandon all hope',
#   'hanne hukkelberg__berlin',
#   'ólafur arnalds__00480729',
#   'boduf songs__quiet when group',
#   'to kill a petty bourgeoisie__lovers',
#   'portishead__machine gun',
#   'opgezwolle__hoedenplank',
#   'a place to bury strangers__lost feeling',
#   'ef__hello scotland',
#   'blueneck__epiphany',
#   'mewithoutyou__paper hanger',
#   'leonard cohen__famous blue raincoat',
#   'isis__in fiction',
#   "i love you but i've chosen darkness__the ghost",
#   'the mountain goats__no children',
#   "hot water music__it's all related",
#   'blueneck__lilitu',
#   'boduf songs__lord of the flies',
#   'la dispute__last blues for bloody knuckles',
#   'zz top__she loves my automobile',
#   'kodiak__beginning',
#   'the black heart rebellion__erase redraw our maps',
#   'amenra__ritual',
#   'battle of mice__bones in the water',
#   'devil sold his soul__clouds',
#   'time to burn__nayeli',
#   'cult of luna__finland',
#   'year of no light__traversée',
#   'time to burn__emma peel',
#   "celeste__comme s'il suffisait de lever le doigt pour refaire",
#   "norma jean__pretty soon i don't know what but something is going to happen",
#   'the spectacle__self and other',
#   'pig destroyer__natasha',
#   'kodiak__mcccxlix the rising end',
#   'plebeian grandstand__doomed to failure',
#   'fever ray__if i had a heart',
#   'conquering animal sound__bear',
#   'joy division__heart and soul',
#   'zz top__she loves my automobile',
#   'austra__the choke',
#   'braveyoung__the weight of loss is whole',
#   'crime in stereo__small skeletal',
#   'true widow__aka',
#   'dälek__culture for dollars'],
#  ['was not was__walk the dinosaur',
#   'mrt__treat your mother right',
#   "ol' dirty bastard__got your money",
#   'the selecter__on my radio',
#   'aux raus__fall',
#   'plastic bertrand__ça plane pour moi',
#   'de jeugd van tegenwoordig__shenkie',
#   'minutemen__corona',
#   'hot club de paris__shipwreck',
#   'chesney hawkes__the one and only',
#   'antoine dodson  the gregory brothers__bed intruder song',
#   'dj paul elstak__luv u more',
#   'dj paul elstak__rainbow in the sky',
#   'madness__baggy trousers'],
#  ['samiam__mexico',
#   'polar bear club__drifting thing',
#   'crime in stereo__small skeletal',
#   'someone still loves you boris yeltsin__think i wanna die',
#   'further seems forever__light up ahead',
#   'blueneck__lilitu',
#   'lemuria__hours',
#   'warren franklin__bro downs know no bounds',
#   'tubelord__cows to the east cities to the west',
#   'hot water music__bleeder',
#   'minus the bear__dog park',
#   'hanne hukkelberg__break my body',
#   'football etc__safety',
#   'flowers from the man who shot your cousin__lay down your arms',
#   'azure ray__november',
#   'the weakerthans__aside',
#   'neutral milk hotel__oh comely',
#   'zz top__she loves my automobile',
#   'on the might of princes__for meg',
#   'very okay__where you go',
#   'against me__borne on the fm waves of the heart',
#   'the fire theft__rubber bands',
#   'good luck__stars were exploding',
#   'rise against__like the angel',
#   'life of agony__weeds'],
#  ['sed non satiata__les hommes sans visage',
#   'la dispute__last blues for bloody knuckles',
#   'heaven in her arms__butterfly in right helicoid',
#   'the black heart rebellion__erase redraw our maps',
#   'pyramids__slow wave',
#   'le pré où je suis mort__une fois de plus',
#   'pianos become the teeth__pensive',
#   'i create__bring me back',
#   'funeral diner__regardless we fall',
#   'mihai edrisch__marcher',
#   'city of caterpillar__when was the last time we painted over the blood on the walls',
#   'city of caterpillar__a heart filled reaction to dissatisfaction',
#   'amenra__from birth to grave from shadow to light',
#   'year of no light__traversée',
#   'devil sold his soul__clouds',
#   'envy__chacun de tes pas',
#   'aussitôt mort__memoria grigia',
#   'pianos become the teeth__houses we die in',
#   'envy__a warm room',
#   'suffocate for fuck sake__blue lights and sunshine'],
#  ['marc anthony__nadie como ella',
#   'gabor szabo__stormy',
#   'al di meola__race with devil on spanish highway',
#   'joe henderson__y todavia la quiero',
#   'eddie palmieri__vamonos pal monte',
#   'prince__musicology',
#   "gregory isaacs__if i don't have you",
#   'marvin gaye__come live with me angel',
#   'quincy jones__summer in the city',
#   'ras kass__miami life',
#   'return to forever__the endless night',
#   "the highlighters__poppin' popcorn",
#   'the mar-keys__plantation inn',
#   'gil scott-heron__did you hear what they said',
#   'uzeb__doobie',
#   'roy ayers__everybody loves the sunshine',
#   'grant green__bottom of the barrel',
#   'los angeles negros__murio la flor',
#   'jorge ben__take it easy my brother charles',
#   'rza__bobby did it spanish fly',
#   'pantera__cemetery gates',
#   'eberhard weber__bird out of cage',
#   'sven libaek__misty canyon',
#   'esg__ufo',
#   'mccoy tyner__impressions',
#   'james brown__blind man can see it',
#   'cymande__dove',
#   'melody gardot__love me like a river does',
#   'nine__whutcha want',
#   'lyn collins__think about it',
#   'marlena shaw__loving you was like a party',
#   "bill withers__she's lonely",
#   'bt__paris',
#   'alice cooper__poison',
#   'johnny cash__hurt',
#   'david axelrod__the mental traveler',
#   'pumpkinhead__emcee',
#   'mobb deep__hell on earth front lines',
#   'gilberto santa rosa__conciencia',
#   'quarteto novo__vim de santana',
#   'héctor lavoe__periódico de ayer',
#   'héctor lavoe__de ti depende',
#   'edit__dex',
#   'zz top__she loves my automobile',
#   'peter frampton__do you feel like we do',
#   'apollo brown__to the melody with love',
#   'mystikal__i smell smoke',
#   'freddie hubbard__lonely soul',
#   'the police__roxanne',
#   'µ-ziq__hasty boom alert',
#   'pat martino__road song',
#   'mobb deep__where ya heart at',
#   'audion__wield',
#   'xploding plastix__kissed by a kisser',
#   'luke vibert__clikilik',
#   'black star__thieves in the night',
#   "the flashbulb__don't wait up",
#   'josé feliciano__la copa rota',
#   'nas__drunk by myself',
#   'aventura__todavia me amas',
#   'aventura__voy malacostumbrado',
#   'nicholas payton__triptych',
#   'goapele__closer',
#   'jay dee__circus',
#   'jamie foxx__overdose',
#   'the headhunters__god make me funky',
#   'fito páez__giros',
#   'dorian concept__vertical output',
#   'immortal technique__leaving the past',
#   'tito puente__tokyo blues',
#   'lloyd__you',
#   'brother ali__picket fence',
#   'enanitos verdes__lamento boliviano',
#   'héctor lavoe__aguanile',
#   'tito puente__hong kong mambo',
#   "oscar d'león__lloraras",
#   'snoop dogg__sexual eruption',
#   'rick james__give it to me baby',
#   'slum village__climax girl shit',
#   'saul williams__our father',
#   'tq__westside',
#   'stark reality__dreams',
#   'mobb deep__survival of the fittest',
#   'bb king__the thrill is gone',
#   'lost boyz__renee',
#   'sandro__porque yo te amo',
#   "ti__still ain't forgave myself",
#   'vicente fernández__el rey',
#   'zz top__she loves my automobile',
#   'the flashbulb__friends under coils',
#   'josé josé__40 y 20',
#   'ricardo arjona__historia de taxi',
#   'death__voice of the soul',
#   'xzibit__alkaholik',
#   'masta ace__beautiful',
#   'michael jackson__pyt pretty young thing',
#   'michael jackson__the lady in my life',
#   'syleena johnson__slowly',
#   'héctor lavoe__triste y vacia',
#   'zombie nation__kernkraft 400',
#   '69 boyz__tootsie roll',
#   'robert miles__children dream version',
#   'crucial conflict__hay',
#   'onyx__veronica',
#   'edit__battling go-go yubari in downtown la',
#   'r kelly__down low double life',
#   'aesop rock__daylight',
#   'cypress hill__boom biddy bye bye',
#   'return to forever__medieval overture',
#   'zz top__she loves my automobile',
#   'nightcrawlers__push the feeling on',
#   'petey pablo__raise up',
#   'gilberto santa rosa__que alguien me diga',
#   'kevin rudolf__great escape',
#   'the notorious big__machine gun funk',
#   'wu-tang clan__triumph',
#   'the whitest boy alive__gravity',
#   'mos def__the panties',
#   'reflection eternal__chaos',
#   'kool__summer madness',
#   'black sheep__the choice is yours',
#   'ice cube__it was a good day',
#   "the sugarhill gang__rapper's delight",
#   'rush__tom sawyer',
#   'poncho sanchez__ican',
#   'kurupt__we can freak it',
#   'ghostface killah__one',
#   "eddie hazel__i want you she's so heavy",
#   "eddie palmieri__vamonos pa'l monte",
#   'zion i__poems 4 post modern decay',
#   'mobb deep__quiet storm',
#   'chris isaak__wicked game',
#   'ja rule__new york',
#   'method man__sweet love',
#   'black moon__stay real',
#   'enanitos verdes__lamento boliviano',
#   'dorian concept__the fucking formula',
#   'metallica__orion',
#   'led zeppelin__dazed and confused',
#   'kraftwerk__trans europe express',
#   'tool__lateralus',
#   'tego calderon__bandoleros',
#   'do or die__po pimp',
#   'nicole wray__make it hot',
#   'zz top__she loves my automobile',
#   'fat joe__that white',
#   'zz top__she loves my automobile',
#   'ugk__one day',
#   'the outlaws__green grass',
#   "dmx__slippin'",
#   "bill withers__i can't write left handed",
#   "ol' dirty bastard__pop shots",
#   'sharon jones and the dap-kings__keep on looking kenny dope remix',
#   'alejandro fernández__como quien pierde una estrella',
#   'victor manuelle__pensamiento y palabra',
#   'everything but the girl__single photek remix',
#   '50 cent__outta control remix'],
#  ['the flashbulb__kirlian choices',
#   'alain caron__slam the clown',
#   'wax and eom__music and liquor',
#   'µ-ziq__hasty boom alert',
#   'edit__dex',
#   'rick ross__maybach music 2',
#   'ludovico einaudi__ascolta',
#   "lil' wayne__prom queen",
#   'chaka khan__fate',
#   'venetian snares__frictional nevada',
#   'prefuse 73__weight watching',
#   'apollo brown__the machine',
#   "ti__still ain't forgave myself",
#   'dam-funk__chocolate',
#   'deceptikon__narcissus',
#   'kerri chandler__bar a thym',
#   'the flashbulb__mellann',
#   'dorian concept__vertical output',
#   'michael bublé__feeling good',
#   'the flashbulb__friends under coils',
#   'flying lotus__breathe  somethingstellar star',
#   'fito páez__giros',
#   'tycho__sunrise projector',
#   'wale__prescription',
#   'zz top__she loves my automobile',
#   'zion__amor de pobre',
#   'zz top__she loves my automobile',
#   "mac dre__since '84",
#   'martín buscaglia__vagabundo',
#   'josé josé__almohada',
#   'keel__tears of fire',
#   'lost tribe__gamemaster',
#   'zz top__she loves my automobile',
#   'dorian concept__clap beep boom',
#   'the flashbulb__delhi ill',
#   'don omar__hasta abajo',
#   'black dada__imma zoe',
#   't-pain__keep going',
#   'xploding plastix__kissed by a kisser',
#   'mount kimbie__maybes',
#   'paco de lucía__cositas buenas tangos',
#   'michael andrews__mad world',
#   "beck__everybody's gotta learn sometimes",
#   'ryan leslie__how it was supposed to be',
#   'the cinematic orchestra__burn out',
#   'contemporary noise quintet__million faces',
#   "la roux__in for the kill skream's let's get ravey remix",
#   "mo' horizons__green day alister johnson remix",
#   'zz top__she loves my automobile',
#   'luis enrique__como volver a ser feliz',
#   'luis enrique__yo no sé mañana',
#   'borgore__saturday night',
#   'electrypnose__juste pour toi',
#   'appleblim__girder',
#   'dorian concept__the fucking formula',
#   'cunninlynguists__brain cell',
#   'mimosa__another day',
#   'usher__there goes my baby',
#   'chris brown__no bullshit',
#   "rusko__you're on my mind baby",
#   'mj cole__sincere nero remix',
#   'clubroot__sempiternal',
#   'pantyraid__get the money',
#   'mimosa__lullabyte',
#   'wisp__hnipian',
#   'trifonic__parks on fire',
#   'simian mobile disco__cruel intentions joker remix',
#   'seu jorge__rebel rebel',
#   'cornell campbell__girl of my dreams',
#   'erik truffaz__the mask',
#   'medeski martin and wood__take me nowhere',
#   'swedish house mafia__one original mix',
#   'passafire__ghost man'],
#  ['rick ross__money make me come', 'pantyraid__get the money', 'ugk__one day'],
#  ['black star__thieves in the night',
#   'joe torres__nightwalk',
#   'melody gardot__love me like a river does',
#   'elaquent__after midnight',
#   'nas__drunk by myself',
#   'immortal technique__leaving the past',
#   'wale__prescription',
#   'paul simon__50 ways to leave your lover',
#   'enanitos verdes__lamento boliviano',
#   'blockhead__quiet storm',
#   'cypress hill__boom biddy bye bye',
#   'mos def__the panties',
#   'kool__summer madness',
#   'trifonic__parks on fire',
#   'question__sun light',
#   'tego calderon__bandoleros',
#   'nicole wray__make it hot',
#   '50 cent__ryder music'],
#  ['nullsleep__dirty rom dance mix',
#   "you love her coz she's dead__young tender hearts beat fast",
#   'iamerror__rainbow road',
#   'sabrepulse__hey kate',
#   'she__a gentle breeze',
#   'covox__switchblade squadron',
#   'random__hux flux deluxe',
#   'sabrepulse__mutant sixty four',
#   'kola kid__cash machine go',
#   'she__ready steady go',
#   "high contrast__everything's different"],
#  ['josé gonzález__teardrop', 'midlake__roscoe', 'midlake__bandits'],
#  ["david lanz__variations on a theme from pachelbel's canon in d major",
#   'helen jane long__expression',
#   'zz top__she loves my automobile',
#   'tim neumark__diamond music',
#   'ludovico einaudi__una mattina',
#   'fariborz lachini__autumn whispers',
#   'yann tiersen__la plage',
#   'yanni__to taketo hold',
#   'yanni__before i go',
#   'philip wesley__tears of the east',
#   'eluvium__radio ballet',
#   'zz top__she loves my automobile',
#   'ludovico einaudi__nuvole nere',
#   'zz top__she loves my automobile'],
#  ['zz top__she loves my automobile',
#   'zz top__she loves my automobile',
#   'zz top__she loves my automobile',
#   'farid farjad__taghatam deh',
#   'zz top__she loves my automobile'],
#  ['zz top__she loves my automobile',
#   'football crazy__ole ole ole',
#   'chris brown__yeah 3x',
#   'europe__the final countdown',
#   'one direction__what makes you beautiful',
#   'tydi__acting crazy',
#   'owl city__when can i see you again',
#   'maroon 5__maps'],
#  ['rihanna__unfaithful instrumental',
#   'yiruma__when the love falls',
#   'philip wesley__tears of the east',
#   'eleni karaindrou__by the sea',
#   'ludovico einaudi__una mattina',
#   'ludovico einaudi__nuvole bianche',
#   'joshua bell__serenade',
#   'zz top__she loves my automobile'],
#  ['james horner__braveheart film score',
#   'loreena mckennitt__la serenissima',
#   'pyotr ilyich tchaikovsky__the swan lake ballet op 20',
#   'rob dougan__clubbed to death kurayamino variation',
#   'johann pachelbel__canon and gigue for 3 violins',
#   'trevor jones__main title',
#   'zz top__she loves my automobile',
#   'fariborz lachini__autumn slumber',
#   'klaus badelt__the black pearl',
#   'clint mansell__lux aeterna',
#   "john williams__schindler's list theme",
#   'francis lai__theme from love story',
#   'myleene klass__for the love of a princess',
#   "david lanz__christofori's dream",
#   'emile pandolfi__time to say goodbye',
#   'escala__palladio',
#   'rob dougan__clubbed to death',
#   'trevor jones__the kiss',
#   'johann pachelbel__canon in d major',
#   'bond__gypsy rhapsody',
#   'yiruma__kiss the rain',
#   'klaus badelt__will and elizabeth',
#   'greg maroney__breathe',
#   'helen jane long__release',
#   'johann pachelbel__canon and gigue in d major',
#   'robert miles__children',
#   "william orbit__barber's adagio for strings excerpt from original version",
#   'michael nyman__the heart asks pleasure first',
#   "israel kamakawiwo'ole__somewhere over the rainbow",
#   'zz top__she loves my automobile',
#   'ennio morricone__chi mai',
#   "ennio morricone__gabriel's oboe",
#   'rachel portman__minor swing',
#   'michael nyman__lost and found',
#   'alan silvestri__forrest gump film score',
#   'james horner__hymn to the sea - stereo',
#   '布袋寅泰__battle without honor or humanity',
#   'zz top__she loves my automobile',
#   'zz top__she loves my automobile',
#   'hans zimmer__time',
#   'jerry goldsmith__end title',
#   "ennio morricone__questa specie d'amore",
#   'hans zimmer__one day',
#   'zz top__she loves my automobile',
#   'the city of prague philharmonic orchestra__the godfather - the godfather waltz',
#   'nino rota__love theme from the godfather',
#   'the czech national symphony orchestra__can-can from orpheus in the underworld',
#   'the lively ones__surf rider',
#   'zz top__she loves my automobile',
#   'ennio morricone__love theme',
#   'the statler brothers__flowers on the wall',
#   'ludovico einaudi__una mattina',
#   'thomas newman__mental boy',
#   'thomas newman__american beauty',
#   'ennio morricone__childhood and manhood',
#   'ennio morricone__first youth'],
#  ['alphaville__big in japan - original',
#   'pet shop boys__go west - 2001 digital remaster',
#   'boney m__ma baker'],
#  ['moriarty__jimmy',
#   'anni b sweet__take on me',
#   'wim mertens__according to the real',
#   'zz top__she loves my automobile',
#   'vangelis__alpha',
#   '2002__stella maris',
#   'vangelis__la petite fille de la mer',
#   'gabriel yared__chile con carne',
#   'suzanne ciani__meeting mozart',
#   'kitaro__caravansary',
#   'escala__requiem for a tower',
#   'jacques brel__vesoul',
#   'jim brickman__never alone',
#   "danny elfman__jack's lament",
#   'michel teló__ai se eu te pego',
#   'zz top__she loves my automobile',
#   'arvo pärt__spiegel im spiegel',
#   'josh groban__you raise me up',
#   'jesse cook__mario takes a walk',
#   'zz top__she loves my automobile',
#   'mike oldfield__moonlight shadow',
#   'despina vandi__opa opa',
#   'david garrett__master of puppets',
#   'the used__the bird and the worm - instrumental',
#   'konami kukeiha club__promise'],
#  ['버스커 버스커__벚꽃 엔딩', 'no__leave the door wide open', 'no__so scared'],
#  ['曲婉婷__我的歌声里',
#   '鄧麗君__月亮代表我的心',
#   'psy__강남스타일',
#   'carly rae jepsen__call me maybe',
#   'yeasayer__blue paper',
#   'bob__both of us feat taylor swift',
#   'frank turner__photosynthesis',
#   'frank turner__four simple words',
#   '王菲__致青春',
#   "alicia keys__if i ain't got you",
#   'boyce avenue__payphone maroon 5 acoustic cover',
#   '苏打绿__我好想你'],
#  ['onerepublic__secrets',
#   'dorian__la tormenta de arena',
#   "sea wolf__you're a wolf",
#   'noize mc__песня для радио',
#   'rihanna__we found love feat calvin harris',
#   'michel teló__ai se eu te pego',
#   'dj fresh feat rita ora__hot right now extended mix',
#   'красная плесень__с 23 февраля',
#   'красная плесень__гимн панков',
#   'the offspring__trust in you',
#   'alizée__moi lolita',
#   'nickelback__when we stand together',
#   'the rasmus__stranger',
#   'bloodhound gang__the ballad of chasey lain',
#   'linkin park__burn it down',
#   'justin bieber__never say never',
#   'justin bieber__baby',
#   'звери__районы-кварталы',
#   'звери__запомни меня',
#   "bon jovi__it's my life",
#   'the kills__black balloon',
#   'fall out boy__thnks fr th mmrs',
#   'ed sheeran__lego house',
#   'avril lavigne__girlfriend',
#   'сектор газа__лирика',
#   "cecilia krull__something's triggered",
#   'bloodhound gang__the bad touch',
#   'stone sour__through glass',
#   's carey__broken'],
#  ['julie london__sway',
#   'nelson riddle__route 66 theme',
#   'jackie gleason__melancholy serenade',
#   'josé feliciano__light my fire',
#   'rufus wainwright__greek song',
#   'ricky nelson__lonesome town',
#   'dusty springfield__the look of love',
#   'the flirtations__nothing but a heartache'],
#  ['los cojolites__luna negra',
#   'tool__vicarious',
#   'madness__one step beyond',
#   'the sugarcubes__deus'],
#  ['slayer__angel of death',
#   'morbid angel__immortal rites',
#   'obituary__infected',
#   'mindrot__dawning',
#   'slayer__hell awaits',
#   'metallica__hit the lights',
#   'metallica__fight fire with fire',
#   'slayer__south of heaven',
#   'megadeth__holy warsthe punishment due',
#   'my dying bride__she is the dark',
#   'my dying bride__the cry of mankind',
#   'anathema__kingdom',
#   'kreator__when the sun burns red',
#   'primordial__fuil arsa',
#   'emperor__into the infinity of thoughts',
#   'enslaved__793 slaget om lindisfarne',
#   'enslaved__storre enn tid - tyngre enn natt',
#   'disembowelment__the tree of life and death',
#   'katatonia__brave',
#   'katatonia__i break',
#   'incantation__impending diabolical conquest',
#   'zz top__she loves my automobile',
#   'ancient rites__the return',
#   'therion__future consciousness',
#   'entombed__left hand path',
#   'dismember__override of the overture',
#   'king crimson__21st century schizoid man',
#   'king crimson__red',
#   'gorguts__obscura',
#   'gorguts__inverted',
#   'cryptopsy__crown of horns',
#   'kataklysm__sorcery',
#   'anathema__sentient',
#   'paradise lost__gothic',
#   'candlemass__solitude',
#   'exodus__bonded by blood',
#   "hawkwind__you shouldn't do that",
#   'hawkwind__brainstorm',
#   "king crimson__lark's tongues in aspic part i",
#   'king crimson__the great deceiver',
#   'hypocrisy__fractured millennium',
#   'drudkh__fading - summoning the rain',
#   'manowar__blood of my enemies',
#   'black sabbath__black sabbath',
#   'black sabbath__wheels of confusion',
#   'black sabbath__turn up the night',
#   'summoning__a new power is rising',
#   'summoning__mirkwood',
#   'amorphis__better unborn',
#   'amorphis__the way',
#   'amorphis__thousand lakes',
#   'burzum__det som en gang var',
#   'burzum__dunkelheit',
#   'atheist__mother man',
#   'cynic__veil of maya',
#   'cathedral__voodoo fire',
#   'cathedral__picture of beauty',
#   'the chasm__from the curse a scourge',
#   'mercyful fate__a dangerous meeting',
#   'nokturnal mortum__the funeral wind born in oriana',
#   'judas priest__exciter',
#   'judas priest__pain killer',
#   'satyricon__walk the path of sorrow',
#   'satyricon__the dawn of a new age',
#   'darkthrone__kathaarian life code',
#   'darkthrone__natassja in eternal sleep',
#   'skepticism__the march and the stream',
#   'morgion__the serpentine scrolls  descent to arawn',
#   'manilla road__riddle of steel',
#   'hypocrisy__the gathering',
#   'immolation__of martyrs and men',
#   'immolation__higher coward',
#   'nocturnus__lake of fire',
#   'neurosis__through silver in blood',
#   'sodom__nuclear winter',
#   'sodom__among the weirdcong',
#   'dark angel__darkness descends',
#   'slayer__war ensemble',
#   'iron maiden__aces high',
#   'immolation__nailed to gold',
#   'immortal__unsilent storms in the north abyss',
#   'primordial__the golden spiral',
#   'primordial__empire falls',
#   "type o negative__i know you're fucking someone else",
#   'anacrusis__sound the alarm',
#   'nick cave  the bad seeds__get ready for love',
#   'anthrax__air',
#   'zz top__she loves my automobile',
#   "aeternus__there's no wine like the bloods crimson",
#   'dark tranquillity__punish my heaven',
#   'god dethroned__serpent king'],
#  ['descendents__pep talk',
#   'descendents__kabuki girl',
#   'descendents__suburban home',
#   'the suicide file__now lie in it',
#   'death before dishonor__born from misery',
#   'death before dishonor__endless suffering',
#   "first blood__next time i see you you're dead",
#   'first blood__unbroken',
#   'first blood__conflict',
#   'ruiner__choke on it',
#   'ruiner__getting over the overs',
#   'ruiner__that stone better be on fire',
#   'killing the dream__critical thought',
#   'killing the dream__if it rains',
#   'killing the dream__fractures',
#   'killing the dream__sick of sleeping',
#   'angry samoans__gas chamber',
#   'angry samoans__lights out',
#   'angry samoans__the todd killings',
#   'paint it black__past tense future perfect',
#   'paint it black__missionary position',
#   'paint it black__the fine art of falling apart',
#   'paint it black__burn the hive',
#   'paint it black__four deadly venoms',
#   'paint it black__cannibal',
#   'paint it black__short changed',
#   'paint it black__four simple steps to total life satisfaction',
#   'paint it black__why film the carnage',
#   "none more black__dinner's for suckers",
#   'none more black__you suck but your peanut butter is ok',
#   'none more black__we dance on the ruins of the stupid stage',
#   'none more black__with the transit coat on',
#   '7 angels 7 plagues__a farewell to a perfect score',
#   'remembering never__incisions',
#   "remembering never__big jim's mistake",
#   'beecher__let them drown',
#   'botch__saint matthew returns to the womb',
#   'botch__transitions from persona to object',
#   'botch__c thomas howell as the soul man',
#   'h2o__unconditional',
#   'h2o__heart on my sleeve',
#   'h2o__mitts',
#   'eighteen visions__russian roulette with a trigger happy manic depressive',
#   'black my heart__what you know about',
#   'martyr ad__american hollow',
#   'martyr ad__the serpent and the flower',
#   'martyr ad__beneath the plague',
#   'martyr ad__bring out your dead',
#   'martyr ad__a suicide note in braille',
#   'with honor__like trumpets',
#   'with honor__you always said',
#   'h2o__one life one chance',
#   'h2o__5 yr plan',
#   'ten yard fight__hardcore pride',
#   'ten yard fight__where i stand',
#   'bloodlined calligraphy__shall we dance',
#   'death before dishonor__count me in',
#   'death before dishonor__break through it all',
#   'death before dishonor__nothing but agony',
#   'death before dishonor__take me away',
#   'death before dishonor__still standing',
#   'good clean fun__who shares wins',
#   'good clean fun__drop the knife',
#   'good clean fun__positively positive',
#   'good clean fun__ex-straightedge-ex',
#   'dillinger four__music is none of my business',
#   'dillinger four__portrait of the artist as a fucking asshole',
#   'dillinger four__the great american going out of business sale',
#   'dillinger four__maximum piss',
#   'dillinger four__q how many punks does it take to change a lightbulb',
#   'dillinger four__d4  putting the f back in art',
#   'dillinger four__noble stabbings',
#   'kid dynamite__rise above',
#   'kid dynamite__heart a tact'],
#  ['ólafur arnalds__1440',
#   'amiina__ugla',
#   'zz top__she loves my automobile',
#   'kiasmos__65',
#   'codes in the clouds__distant street lights',
#   'basement jaxx__good luck',
#   'free the robots__jazzhole',
#   'caribou__sun',
#   'yaron herman__toxic',
#   'mike stern__last one down',
#   'ef__hello scotland',
#   'nils frahm__tristana',
#   'hidden orchestra__antiphon',
#   'heirs__hunter',
#   'philip jeck__june',
#   'a winged victory for the sullen__we played some open chords',
#   'thisquietarmy__revival',
#   'bersarin quartett__der mond der schnee und du',
#   'greg haines__ernetti',
#   'blueneck__pneumothorax',
#   'moritz von oswald trio__dark',
#   'carlos cipa__the whole truth',
#   'murcof__cielo',
#   'poppy ackroyd__mechanism',
#   'poets of the fall__roses',
#   'sigur rós__hoppípolla',
#   'caspian__hymn for the greatest generation',
#   'federico albanese__beyond the milk wood',
#   'sebastian plano__living',
#   'demdike stare__forest of evil dusk',
#   'tycho__awake',
#   'we were promised jetpacks__quiet little voices',
#   'hauschka__elizabeth bay'],
#  ['jonathan coulton__still alive',
#   'kelly bailey__hazardous environments',
#   'russell brower derek duke matt uelmen__the burning legion main title',
#   'garry schyman__bioshock main theme the ocean on his shoulders',
#   'garry schyman__welcome to rapture',
#   'adam skorupa__dusk of a northern kingdom',
#   'bear mccreary__colonial anthem',
#   'john murphy__sunshine',
#   'zz top__she loves my automobile',
#   'chris hülsbeck__licht am ende des tunnels suite',
#   'zz top__she loves my automobile',
#   'chris hülsbeck__jim power in mutant planet main theme',
#   'chris hülsbeck__grand monster slam opening fanfare',
#   'hans zimmer__160 bpm',
#   'michael giacchino__roar',
#   'zz top__she loves my automobile',
#   'grandaddy__am 180',
#   'brian eno__an ending ascent',
#   'john williams__flight from peru',
#   'james newton howard__the gravel road',
#   'bear mccreary__kara remembers',
#   'bear mccreary__diaspora oratorio',
#   'bear mccreary__karas coordinates',
#   'bear mccreary__gaetas lament',
#   'bear mccreary__laura runs',
#   "tyler bates__hank's theme",
#   'john ottman__operation valkyrie',
#   'james hannigan__soviet march',
#   'regina spektor__us',
#   'leon willett__the hospital room',
#   'leon willett__dreamfall theme',
# ...
#   'heaven 17__temptation',
#   'unkle__kaned and abel',
#   'black grape__reverend black grape',
#   'stereophonics__devil',
#   'kaiser chiefs__oh my god',
#   'the magic numbers__hymn for her',
#   'depeche mode__personal jesus',
#   'unkle__lonely soul',
#   'george michael__faith',
#   'gnarls barkley__go go gadget gospel',
#   'the velvet underground__sunday morning',
#   'orbital__satan',
#   "gorillaz__don't get lost in heaven",
#   'simple minds__promised you a miracle',
#   'arcade fire__neon bible',
#   'rob dougan__furious angels',
#   'foo fighters__halo',
#   'dusty springfield__son of a preacher man',
#   'depeche mode__judas',
#   'incredible bongo band__in-a-gadda-da-vida',
#   'genesis__jesus he knows me',
#   'rem__losing my religion',
#   'röyksopp__eple',
#   'aretha franklin__i say a little prayer',
#   'the stone roses__i am the resurrection',
#   'oasis__live forever',
#   'pete namlook__spiritual invocation',
#   "the smiths__heaven knows i'm miserable now",
#   "dj lobsterdust__it's fun to smoke dust queen vs satan"],
#  ['u2__numb',
#   'inxs__disappear',
#   'gnarls barkley__crazy',
#   'john lennon__imagine',
#   'radiohead__just',
#   'adamski__killer',
#   'def leppard__animal',
#   'prince__kiss',
#   'peggy lee__fever',
#   'john lennon__woman',
#   'the verve__sonnet',
#   'the crazy world of arthur brown__fire',
#   'edwin starr__war',
#   'radiohead__creep radio edit',
#   'u2__one',
#   'blondie__atomic',
#   'elvis costello__she',
#   'josé gonzález__heartbeats',
#   'aretha franklin__think',
#   'tenacious d__tribute',
#   'michael jackson__bad',
#   'portishead__numb',
#   'supergrass__alright'],
#  ['m83__intro ft zola jesus',
#   'm83__midnight city',
#   'm83__reunion',
#   'm83__where the boats go',
#   'm83__wait',
#   'm83__train to pluton',
#   'm83__claudia lewis',
#   'm83__this bright flash',
#   'm83__when will you come home ',
#   'm83__soon my friend',
#   'm83__my tears are becoming a sea',
#   'm83__new map',
#   'm83__ok pal',
#   'm83__another wave from you',
#   'm83__splendor',
#   'm83__year one one ufo',
#   'm83__fountains',
#   'm83__steve mcqueen',
#   'm83__echoes of mine',
#   'm83__klaus i love you',
#   'm83__outro'],
#  ["the rolling stones__she's a rainbow - stereo full version  with intro",
#   'nena__99 red balloons',
#   'editors__orange crush',
#   'joni mitchell__big yellow taxi',
#   "booker t  the mg's__green onions",
#   'electric light orchestra__mr blue sky',
#   'epica__indigo',
#   'coldplay__violet hill',
#   "klaxons__gravity's rainbow"],
#  ['brian eno__stars',
#   'akira kosemura__garden',
#   'stars of the lid__the evil that never arrived',
#   'helios__dragonfly across an ancient sky',
#   'tycho__past is prologue',
#   "ulrich schnauss__nobody's home",
#   'aphex twin__parallel stripes',
#   'gutevolk__antenna'],
#  ['the beatles__birthday',
#   'andrew bird__the happy birthday song',
#   'stevie wonder__happy birthday',
#   'blur__birthday',
#   'the birthday massacre__happy birthday',
#   'moby__sunday the day before my birthday'],
#  ['the innocence mission__i never knew you from the sun',
#   'the innocence mission__beautiful change',
#   'the innocence mission__martha avenue love song',
#   'the innocence mission__that was another country',
#   'the innocence mission__keeping awake',
#   'the innocence mission__brave',
#   'the innocence mission__happy the end',
#   "the innocence mission__everything's different now",
#   'the innocence mission__wonder of birds',
#   'the innocence mission__you chase the light',
#   'the innocence mission__medjugorje',
#   'fear falls burning__frenzy of the absolute',
#   'auburn lull__broken heroes',
#   'matthew robert cooper__miniature 3',
#   'windy__surfacing',
#   'brian mcbride__for those who hesitate',
#   'eluvium__calm of the cast-light cloud'],
#  ['scarlett johansson__falling down', 'mythos__adagio'],
#  ['grouper__sang their way',
#   'grouper__adorned',
#   'natural snow buildings__ i came down here',
#   'belong__beeside',
#   'sylvain chauveau__géographie intime',
#   'pausal__heroesdogs',
#   'tim hecker__dungeoneering',
#   'grouper__they moved everything',
#   'grouper__close cloak',
#   'chris herbert__untitled interlude i',
#   'grouper__imposter in the sky',
#   'inca ore__vista maria',
#   'grouper__shadow rise drowned',
#   'valet__fire',
#   'zola jesus__clay bodies',
#   'religious knives__everything happens twice',
#   'zz top__she loves my automobile',
#   "yellow6__i know i shouldn't but i do"],
#  ['biosphere__kobresia',
#   'hammock__gold star mothers',
#   'helios__dragonfly across an ancient sky',
#   'grouper__they moved everything',
#   'aix em klemm__3x2exit',
#   'eluvium__reciting the airships',
#   "jasper tx__blown out to sea i'm never coming back",
#   'windy__forever',
#   'belong__remove the inside',
#   'aix em klemm__sparkwood and twentyone',
#   'windy__resolution',
#   'keith fullerton whitman__modena',
#   'nadja__stays demons',
#   'tarentel__for carl sagan',
#   'zz top__she loves my automobile',
#   'stars of the lid__december hunting for vegetarian fuckface',
#   'emeralds__alive in the sea of information',
#   'white rainbow__middle',
#   'panamerican__still swimming',
#   'growing__firmament',
#   'zola jesus__clay bodies',
#   'loscil__windless',
#   "slow dancing society__west of 4th kristina's song"],
#  ['belong__girl from new york',
#   'aix em klemm__the luxury of dirt',
#   'loscil__cotom',
#   'lawrence english__desert road',
#   'christopher bissonnette__jour et nuit',
#   'last days__swimming pools at night',
#   'growing__peace offering',
#   'growing__epochal reminiscence',
#   'worrytrain__achtung god',
#   'keith fullerton whitman__acgtr svp',
#   'belong__remove the inside',
#   'bell orchestre__elephants',
#   'aix em klemm__sophteonal',
#   'klimek__for jim hall',
#   'william basinski__dlp 22',
#   'aix em klemm__3x2exit',
#   'benoît pioulard__moth wings',
#   'aidan baker__the sea swells a bit',
#   'loscil__chinook',
#   'chris herbert__untitled interlude i',
#   'slow dancing society__be there',
#   'growing__firmament'],
#  ['medicine__one more',
#   'menace ruine__dismantling',
#   'galaxie 500__decomposing trees',
#   'pillowdiver__sleeping pill one',
#   'slowdive__she calls',
#   'aix em klemm__prue lewarne',
#   'natural snow buildings__sun',
#   'bell orchestre__elephants',
#   'valet__we went there',
#   'emeralds__living room',
#   'valley of the giants__whaling tale',
#   'menace ruine__surface vessel'],
#  ['william basinski__dlp 22',
#   'taylor deupree__landing',
#   'william basinski__dp 4',
#   'labradford__p',
#   'william basinski__melancholia 6',
#   'belong__who told you this room exists'],
#  ['lattice__song in the key of glass - movement 1',
#   'the dead texan__the 6 million dollar sandwich',
#   'brian mcbride__overture for other halfs',
#   'brian mcbride__our last moment in song',
#   'brian mcbride__silent motels',
#   'brian mcbride__prelude',
#   "the dead texan__glen's goo",
#   'stars of the lid__the daughters of quiet minds',
#   'jatun__a reason for enigmas',
#   'stars of the lid__dungtitled in a major',
#   'eluvium__seeing you off the edges',
#   'eluvium__everything to come',
#   'lattice__lovesong',
#   'proton kinoun__illimitable',
#   'paul van dyk__nothing but you pvd radio mix',
#   'stars of the lid__even out 2b',
#   'aix em klemm__the girl with the flesh colored crayon',
#   'paul van dyk__spellbound',
#   'paul oakenfold__southern sun',
#   'ferry corsten__down on love',
#   'rank 1__airwave rank 1 vs dutch force mix',
#   'william basinski__watermusic',
#   'distant fires burning__messier 1 ex-supernova',
#   'tear ceremony__jean seberg circa 1958',
#   'lull__slow fall inward',
#   'alio die__gli ossidi del divenire',
#   'dark muse__queen of the world of spirits',
#   'tear ceremony__the speed of film',
#   'kammarheit__the ruins and the serene',
#   'contrastate__an end marked by pessimism',
#   'steve roach__reflections in suspension',
#   'robert rich__the road to wirikuta',
#   'thomas köner__nuuk night',
#   "dahlia's tear__5th sky within a dying single ember",
#   'mj harris and bill laswell__capacious',
#   'raspad atoma__vanishing line',
#   'polmo polpo__complete breath',
#   'william basinski__untitled',
#   'lawrence english__end game',
#   'nadja__skin turns to glass',
#   'tim hecker__neither more nor less',
#   'stars of the lid__hiberner toujours',
#   'fennesz__011',
#   'first human ferro__never to have lived is best',
#   'windy__la douleur',
#   'harold budd__il leopardo delle nevi',
#   'stars of the lid__central texas',
#   'eluvium__taken',
#   'eluvium__calm of the cast-light cloud',
#   'eluvium__an accidental memory',
#   'eluvium__new animals from the air',
#   'eluvium__an accidental memory in the case of death',
#   'eluvium__one',
#   'this will destroy you__the world is our ___',
#   'stars of the lid__apreludes in c sharp major',
#   'the dead texan__when i see scissors i cannot help but think of you',
#   'william basinski__melancholia 1',
#   'the dead texan__the 6 million dollar sandwich',
#   'eluvium__i am so much more me that you are perfectly you',
#   'stars of the lid__the evil that never arrived',
#   'panamerican__2-sided',
#   'harold budd__the white arcades',
#   'gas__pop 1',
#   '1 mile north__in 1983 he loved to fly',
#   'brian mcbride__i will',
#   'zz top__she loves my automobile',
#   'kammarheit__a room between the rooms',
#   'william basinski__melancholia 13',
#   'loscil__motoc',
#   'brian mcbride__for those who hesitate',
#   'william basinski__melancholia xiv',
#   'william basinski__melancholia xiii',
#   'william basinski__melancholia xii',
#   'tor lundvall__my weakness',
#   'stars of the lid__articulate silences part 1',
#   'implicit audio frequency__state of mind winter 73',
#   'proton kinoun__silver satellite',
#   'ulf lohmann__java',
#   'aidan baker__fantasma-parastasie',
#   'lichens__m st r ng w tchcr ft l v ng n sp r t',
#   'robert henke__layer 001',
#   'william basinski__melancholia i',
#   'eluvium__area 41',
#   'deaf center__walk',
#   'steve roach__infinite shore',
#   'pausal__heroesdogs',
#   'eluvium__show us our homes',
#   'tim hecker__harmony in blue iii',
#   'zz top__she loves my automobile',
#   'loscil__zephyr',
#   'william basinski__melancholia 10',
#   'stars of the lid__broken harbors part 3',
#   'hammock__eighty-four thousand hymns',
#   'william basinski__dlp 3',
#   'lawrence english__desert road',
#   'the dead texan__a chronicle of early failures pt one',
#   'stars of the lid__broken harbors part 1',
#   'tim hecker__balkanize-you',
#   'polmo polpo__rottura',
#   "belong__i'm too sleepyshall we swim",
#   'sigur rós__takk',
#   "colleen__i'll read you a story",
#   'grouper__little gray cat',
#   'max richter__song',
#   'sylvain chauveau__pauvre simon',
#   'loscil__discrete entropy',
#   'zz top__she loves my automobile',
#   'gas__pop',
#   'markus guentner__pilot',
#   'gas__microscopic',
#   'grouper__way their crept',
#   'benoît pioulard__sweep generator',
#   'tim hecker__counter attack',
#   'belong__beeside',
#   'thomas köner__amras',
#   'loscil__nautilus',
#   'gas__pop 2',
#   'william basinski__despair',
#   'tetsu inoue__magnetic field',
#   'william basinski__the garden of brokenness',
#   'deepspace__another empty galaxy',
#   'hyperwind__shady wastes',
#   'rafter__ending',
#   'eluvium__indoor swimming at the space station',
#   'stars of the lid__the mouthchew',
#   'loscil__kursk',
#   'brian mcbride__the guilt of uncomplicated thoughts',
#   'stars of the lid__articulate silences part 2',
#   "brian mcbride__a gathering to lead me when you're gone",
#   'chihei hatakeyama__bonfire on the field',
#   'windy__the silent ocean',
#   'eluvium__intermission',
#   'celer__anacapri',
#   'grouper__black blood',
#   "valet__angels can't stop",
#   'natural snow buildings__with a stolen red lipstick bible on her side',
#   'hammock__i can almost see you',
#   'grouper__close cloak',
#   'grouper__black out'],
#  ['deerhunter__strange lights',
#   'belong__beeside',
#   'the caretaker__you and the night',
#   'yume bitsu__team yume'],
#  ['rank 1__airwave rank 1 vs dutch force mix',
#   'infected mushroom__heavyweight',
#   'rank 1__airwave',
#   'cygnus x__the orange theme',
#   'bt__remember',
#   'dj shog__rush hour',
#   'william basinski__watermusic',
#   'paul van dyk__nothing but you',
#   'dj sammy__why radio edit',
#   'paul van dyk__travelling',
#   'ferry corsten__lef',
#   'armin van buuren__imagine',
#   'rank 1__awakening radio edit',
#   'thomas bronzwaer__certitude',
#   'system f__out of the blue',
#   'markus schulz__the new world original mix',
#   'atb__la nights',
#   'paul oakenfold__zoo york',
#   'kyau vs albert__kiksu original mix',
#   "solar stone__seven cities solar stone's atlantis mix"],
#  ['cheryl cole__amnesia',
#   'kanye west__all of the lights',
#   'lady gaga__the edge of glory'],
#  ['la roux__bulletproof', '30 seconds to mars__attack'],
#  ['sofa surfers__hardwire'],
#  ['zz top__she loves my automobile'],
#  ['riverside__out of myself',
#   'porcupine tree__the sound of muzak',
#   'porcupine tree__trains',
#   'oceansize__the charm offensive',
#   'yes__heart of the sunrise',
#   'yes__south side of the sky',
#   'rush__freewill',
#   'rush__subdivisions',
#   'pink floyd__hey you',
#   'genesis__abacab',
#   'dream theater__panic attack',
#   'dream theater__the dark eternal night',
#   'rush__red sector a',
#   'the mars volta__the widow',
#   'the mars volta__roulette dares the haunt of'],
#  ['1200 micrograms__dmt',
#   'rank 1__such is life',
#   'marco v__simulated',
#   'sander van doorn__riff',
#   'ernesto vs bastian__thrill',
#   'talamasca__capricorn',
#   '1200 micrograms__dna',
#   "infected mushroom__can't stop",
#   'protoculture__high orbit',
#   'sun project__wiper mk iii',
#   'tiësto__forever today',
#   'electric universe__you decide',
#   'younger brother__magic monkey juice',
#   'juno reactor__swamp thing',
#   'cosmosis__dance of the cosmic serpent',
#   'younger brother__weird on a monday night',
#   'rinkadink__basshead',
#   'infected mushroom__slowly',
#   '1200 micrograms__acid for nothing',
#   'alien project__rapiginio',
#   'hallucinogen__snakey shaker',
#   'gms__baty boy',
#   'shpongle__outer shpongolia',
#   'shpongle__circuits of the imagination',
#   'carbon based lifeforms__neurotransmitter',
#   'sun project__cyber space sucker',
#   'yahel__liquid love',
#   'shpongle__botanical dimensions',
#   'shpongle__and the day turned to night',
#   'gms__lord of the rings',
#   'hallucinogen__solstice warwick bassmonkey mix',
#   '1200 micrograms__language of the future',
#   'astral projection__people can fly',
#   'talamasca__cancer',
#   'astrix__side effect',
#   'electric universe__high fly',
#   'ananda shake__meshel 6 days',
#   'talpa__miss ivon',
#   'astrix__poison',
#   'entheogenic__twilight eyes',
#   'entheogenic__rio barra',
#   'carbon based lifeforms__refraction 133',
#   'doof__mars needs women',
#   'the peaking goddess collective__hyperspace',
#   'rui da silva__touch me original mix',
#   'rui da silva__touch me',
#   'shpongle__invocation',
#   'sesto sento__perfect day',
#   'infected mushroom__project 100',
#   'sub6__droid save da queen x-noize rmx',
#   'hallucinogen__snarling black mabel',
#   'alien project__groovy',
#   'alien project__nitro punch',
#   'shpongle__dorset perception',
#   'beat hackers__experience',
#   'astrix__on fire',
#   'astrix__tweaky',
#   'gogol bordello__start wearing purple',
#   'talamasca__a frenchman in cape town',
#   'transa__enervate',
#   'mekkanikka__black jack',
#   'zz top__she loves my automobile',
#   'infected mushroom__tommy the bat',
#   'allure__no question',
#   'a boy called joni__green astronauts',
#   'astral projection__nilaya',
#   'infected mushroom__vicious delicious',
#   'tag team__whoomp there it is',
#   'astrix__crystal sequence',
#   'salt-n-pepa__push it',
#   'tone-lōc__funky cold medina'],
#  ["mc hammer__u can't touch this",
#   'sir mix-a-lot__baby got back',
#   'c2bc music factory__gonna make you sweat everybody dance now',
#   'salt-n-pepa__push it',
#   'tag team__whoomp there it is',
#   'pm dawn__set adrift on memory bliss',
#   "right said fred__i'm too sexy",
#   'gorillaz__clint eastwood',
#   'nelly__just a dream',
#   'eminem__criminal',
#   'mos def__hip hop'],
#  ['diane arkenstone__the secret garden', 'earth trybe__shirashikkur'],
#  ['disturbed__voices',
#   'anthrax__among the living',
#   "hellyeah__alcohaulin' ass",
#   'talamasca__aries'],
#  ['alien project__groovy',
#   '1200 micrograms__dmt',
#   '1200 micrograms__ayahuasca',
#   'younger brother__i am a freak',
#   'astrix__valirus',
#   'shpongle__and the day turned to night',
#   'electric universe__the prayer'],
#  ...]

# %%
train_data, test_data = train_test_split(convertedPlayLists, test_size=0.2, random_state=42)

# %%
playlist_lengths = [len(playlist) for playlist in train_data]

# %%
plt.figure(figsize=(10, 6))
plt.hist(playlist_lengths, bins=50)
plt.xlabel("Playlist Length")
plt.ylabel("Number of Playlists")
plt.title("Playlist Length Distribution")
plt.show()

# %%
all_tracks = [track for playlist in train_data for track in playlist]

# %%
counterDict = Counter(all_tracks)
for k,v in list(counterDict.items())[:5]:
    print(k, v)
# Out:
# nitzer ebb__i give to you 9
# nitzer ebb__come alive 2
# nachtmahr__feuer frei 10
# the last dance__once beautiful 3
# clint mansell__the last man 19

# %%
freqs = [count for _, count in counterDict.most_common()]
ranks = range(1, len(freqs) + 1)

plt.figure(figsize=(10, 6))
plt.loglog(ranks, freqs)
plt.xlabel("Rank")
plt.ylabel("Frequency")
plt.title("Track Frequency Distribution")
plt.show()

# %%
top20_tracks = counterDict.most_common(20)
tracks, counts = zip(*top20_tracks)

plt.figure(figsize=(12, 6))
plt.barh(tracks, counts)
plt.xlabel("Frequency")
plt.title("Top 20 Most Frequent Tracks")
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()

# %%
top20_tracks = counterDict.most_common(20)

print("Top 20 Most Frequent Tracks:")
for i, (track, count) in enumerate(top20_tracks, 1):
    print(f"{i}. {track} → {count}")
# Out:
# Top 20 Most Frequent Tracks:
# 1. zz top__she loves my automobile → 24721
# 2. massive attack__teardrop → 392
# 3. joy division__love will tear us apart → 369
# 4. radiohead__karma police → 347
# 5. nirvana__smells like teen spirit → 331
# 6. mgmt__kids → 330
# 7. radiohead__creep → 329
# 8. oasis__wonderwall → 318
# 9. the rolling stones__paint it black → 317
# 10. the killers__mr brightside → 313
# 11. mgmt__time to pretend → 298
# 12. franz ferdinand__take me out → 282
# 13. muse__starlight → 271
# 14. led zeppelin__stairway to heaven → 270
# 15. depeche mode__enjoy the silence → 268
# 16. system of a down__chop suey → 260
# 17. kings of leon__sex on fire → 259
# 18. coldplay__viva la vida → 255
# 19. radiohead__paranoid android → 255
# 20. pink floyd__wish you were here → 254

# %%
total_unique = len(counterDict)
hapax = sum(1 for count in counterDict.values() if count == 1)
coverage = hapax / total_unique * 100

print(f"Total unique tracks: {total_unique}")
print(f"Hapax legomena (appearing only once): {hapax}")
print(f"Coverage (hapax / total): {coverage:.2f}%")
# Out:
# Total unique tracks: 391991
# Hapax legomena (appearing only once): 216260
# Coverage (hapax / total): 55.17%

# %%
baseModel = Word2Vec (
    sentences=train_data,
    vector_size=100,
    window=5,
    min_count=5,
    sg=1,
    ns_exponent=0.75,
    workers=4,
    epochs=5
)

# %%
def ContextAveraging(model, k=10):
    total_score = 0
    total_trial = 0
    total_ncdg = 0
    for sentence in test_data:
        total_embedding = 0
        count = 0
        lastSong = sentence[-1]
        calculatorSentence = sentence[:-1]
        for song in calculatorSentence:
            if song in model.wv:
                total_embedding += model.wv[song]
                count += 1
        if lastSong not in model.wv:
            continue
        if count == 0:
            continue
        avg_embedding = total_embedding / count
        predictionList = model.wv.most_similar(positive=[avg_embedding], topn=k)
        songList = [song for song, score in predictionList]
        if lastSong in songList:
            total_score += 1
            rank = songList.index(lastSong) + 1
            total_ncdg += 1 / math.log2(rank+1)
        total_trial += 1
    predictionRateHR = total_score / total_trial
    predictionRateNDCG = total_ncdg / total_trial
    return predictionRateHR, predictionRateNDCG
            
print(ContextAveraging(baseModel))
# Out:
# (0.026797984425103068, 0.019943111572830116)

# %%
def SingleQuerySong(model, k=10):
    total_score = 0
    total_trial = 0
    total_ncdg = 0
    for sentence in test_data:
        if len(sentence) < 2:
            continue
        lastSong = sentence[-1]
        secondLastSong = sentence[-2]
        if lastSong not in model.wv or secondLastSong not in model.wv:
            continue
        secondLastSongEmbedding = model.wv[secondLastSong]
        predictionList = model.wv.most_similar(positive=[secondLastSongEmbedding], topn=k)
        songList = [song for song, score in predictionList]
        if lastSong in songList:
            total_score += 1
            rank = songList.index(lastSong) + 1
            total_ncdg += 1 / math.log2(rank+1)
        total_trial += 1
    predictionRateHR = total_score / total_trial
    predictionRateNDCG = total_ncdg / total_trial
    return predictionRateHR, predictionRateNDCG

print(SingleQuerySong(baseModel))
# Out:
# (0.04147786685256187, 0.02431671134843077)

# %%
def BestModelForEpochs():
    epoch_values = [5, 20, 50]
    results = {}

    for epoch in epoch_values:
        model_temp = Word2Vec(
            sentences=train_data,
            vector_size=100,
            window=5,
            min_count=5,
            sg=1,
            negative=5,
            ns_exponent=0.75,
            workers=4,
            epochs=epoch
        )

        result = SingleQuerySong(model_temp)[0]
        results[epoch] = result

    for epoch in results:
        result = results[epoch]
        print(f"epoch={epoch}: HR={result:.4f}")
        if result == max(results.values()):
            return epoch

bestEpoch = BestModelForEpochs()
# Out:
# epoch=5: HR=0.0408
# epoch=20: HR=0.0673
# epoch=50: HR=0.0683
# 50

# %%
def BestModelForNsExponent():
    ns_exponent_values = [-1.0, -0.5, 0, 0.5, 0.75, 1.0]
    results = {}


    for ns_exponent in ns_exponent_values:
        model_temp = Word2Vec(
            sentences=train_data,
            vector_size=100,
            window=5,
            min_count=5,
            sg=1,
            negative=5,
            ns_exponent=ns_exponent,
            workers=4,
            epochs=bestEpoch
        )

        result = SingleQuerySong(model_temp)[0]
        results[ns_exponent] = result 

    for ns_exponent in results:
        result = results[ns_exponent]
        print(f"ns_exponent={ns_exponent}: HR={result:.4f}")
        if results[ns_exponent] == max(results.values()):
            return ns_exponent

bestNs = BestModelForNsExponent()
bestNs
# Out:
# ns_exponent=-1.0: HR=0.0732
# ns_exponent=-0.5: HR=0.0749
# -0.5

# %%
def BestModelForWindow():
    window_values = [5, 20, 40]
    results = {}

    for window in window_values:
        model_temp = Word2Vec(
            sentences=train_data,
            vector_size=100,
            window=window,
            min_count=5,
            sg=1,
            negative=5,
            ns_exponent=bestNs,
            workers=4,
            epochs=bestEpoch
        )

        result = SingleQuerySong(model_temp)[0]
        results[window] = result

    for window in results:
        result = results[window]
        print(f"window={window}: HR={result:.4f}")
        if result == max(results.values()):
            return window
        
bestWindow = BestModelForWindow()
bestWindow
# Out:
# window=5: HR=0.0760
# window=20: HR=0.0864
# window=40: HR=0.0892
# 40

# %%
def BestModelForNegative():
    negative_values = [5, 10, 15]
    results = {}

    for negative in negative_values:
        model_temp = Word2Vec(
            sentences=train_data,
            vector_size=100,
            window=bestWindow,
            min_count=5,
            sg=1,
            negative=negative,
            ns_exponent=bestNs,
            workers=4,
            epochs=bestEpoch
        )

        result = SingleQuerySong(model_temp)[0]
        results[negative] = result

    for negative in negative_values:
        result = results[negative]
        print(f"negative={negative}: HR={result:.4f}")
        if result == max(results.values()):
            return negative
        
bestNegative = BestModelForNegative()
bestNegative
# Out:
# negative=5: HR=0.0885
# negative=10: HR=0.0927
# negative=15: HR=0.0938
# 15

# %%
def BestModelForMinCount():
    min_count_values = [3, 5, 10]
    results = {}

    for min_count in min_count_values:
        model_temp = Word2Vec(
            sentences=train_data,
            vector_size=100,
            window=bestWindow,
            min_count=min_count,
            sg=1,
            negative=bestNegative,
            ns_exponent=bestNs,
            workers=4,
            epochs=bestEpoch
        )

        result = SingleQuerySong(model_temp)[0]
        results[min_count] = result

    for min_count in min_count_values:
        result = results[min_count]
        print(f"min_count={min_count}: HR={result:.4f}")
        if result == max(results.values()):
            return min_count
        
bestMinCount = BestModelForMinCount()
bestMinCount
# Out:
# min_count=3: HR=0.0702
# min_count=5: HR=0.0979
# min_count=10: HR=0.1342
# 10

# %%
def BestModelForVectorSize():
    vector_size_values = [50, 100, 300]
    results = {}

    for vector_size in vector_size_values:
        model_temp = Word2Vec(
            sentences=train_data,
            vector_size=vector_size,
            window=bestWindow,
            min_count=bestMinCount,
            sg=1,
            negative=bestNegative,
            ns_exponent=bestNs,
            workers=4,
            epochs=bestEpoch
        )

        result = SingleQuerySong(model_temp)[0]
        results[vector_size] = result

    maxVectorSize = 0
    for vector_size in vector_size_values:
        result = results[vector_size]
        print(f"vector_size={vector_size}: HR={result:.4f}")
        if result == max(results.values()):
            maxVectorSize = vector_size
    return maxVectorSize
        
bestVectorSize = BestModelForVectorSize()
bestVectorSize
# Out:
# vector_size=50: HR=0.1291
# vector_size=100: HR=0.1359
# vector_size=300: HR=0.1319
# 100

# %%
def BestModelForSg():
    sg_values = [0, 1]
    results = {}

    for sg in sg_values:
        model_temp = Word2Vec(
            sentences=train_data,
            vector_size=bestVectorSize,
            window=bestWindow,
            min_count=bestMinCount,
            sg=sg,
            negative=bestNegative,
            ns_exponent=bestNs,
            workers=4,
            epochs=bestEpoch
        )

        result = SingleQuerySong(model_temp)[0]
        results[sg] = result

    maxSg = 0
    for sg in sg_values:
        result = results[sg]
        print(f"sg={sg}: HR={result:.4f}")
        if result == max(results.values()):
            maxSg = sg
    return maxSg
        
bestSg = BestModelForSg()
bestSg
# Out:
# sg=0: HR=0.1140
# sg=1: HR=0.1331
# 1

# %%
final_model = Word2Vec(
    sentences=train_data,
    vector_size=bestVectorSize,
    window=bestWindow,
    min_count=bestMinCount,
    sg=bestSg,
    negative=bestNegative,
    ns_exponent=bestNs,
    workers=4,
    epochs=bestEpoch
)

# %%
# APPROACH 2
print("APPROACH-2")
for k in [5, 10, 20, 50]:
    hr, ndcg = SingleQuerySong(final_model, k=k)
    print(f"K={k}: HR={hr:.4f}, NDCG={ndcg:.4f}")
# Out:
# APPROACH-2
# K=5: HR=0.0938, NDCG=0.0573
# K=10: HR=0.1303, NDCG=0.0689
# K=20: HR=0.1814, NDCG=0.0818
# K=50: HR=0.2364, NDCG=0.0928

# %%
# APPROACH 1
print("APPROACH-1")
for k in [5, 10, 20, 50]:
    hr, ndcg = ContextAveraging(final_model, k=k)
    print(f"K={k}: HR={hr:.4f}, NDCG={ndcg:.4f}")
# Out:
# APPROACH-1
# K=5: HR=0.0653, NDCG=0.0448
# K=10: HR=0.1044, NDCG=0.0573
# K=20: HR=0.1479, NDCG=0.0683
# K=50: HR=0.2206, NDCG=0.0828

# %%
similar = final_model.wv.most_similar("queen__bohemian rhapsody", topn=10)
for song, score in similar:
    print(f"{song}: {score:.4f}")
# Out:
# queen__we will rock you: 0.8262
# queen__we are the champions: 0.7578
# queen__don't stop me now: 0.7417
# queen__killer queen: 0.7399
# queen__somebody to love: 0.7296
# queen__another one bites the dust: 0.7272
# queen__the show must go on: 0.7105
# queen__bicycle race: 0.6945
# led zeppelin__stairway to heaven: 0.6934
# queen__i want to break free: 0.6880

# %%
similar = final_model.wv.most_similar("led zeppelin__stairway to heaven", topn=10)
for song, score in similar:
    print(f"{song}: {score:.4f}")
# Out:
# led zeppelin__whole lotta love: 0.8097
# led zeppelin__immigrant song: 0.7718
# led zeppelin__kashmir: 0.7619
# deep purple__smoke on the water: 0.7553
# led zeppelin__black dog: 0.7469
# pink floyd__wish you were here: 0.7466
# led zeppelin__since i've been loving you: 0.7168
# pink floyd__comfortably numb: 0.7073
# queen__bohemian rhapsody: 0.6934
# led zeppelin__dazed and confused: 0.6848

# %%
similar = final_model.wv.most_similar("michael jackson__thriller", topn=10)
for song, score in similar:
    print(f"{song}: {score:.4f}")
# Out:
# michael jackson__beat it: 0.8691
# michael jackson__bad: 0.8649
# michael jackson__billie jean: 0.8445
# michael jackson__smooth criminal: 0.8199
# michael jackson__black or white: 0.7903
# michael jackson__man in the mirror: 0.7705
# michael jackson__the way you make me feel: 0.7360
# michael jackson__rock with you: 0.7324
# michael jackson__dirty diana: 0.7173
# michael jackson__wanna be startin' somethin': 0.7036

# %%
similar = final_model.wv.most_similar("pink floyd__wish you were here", topn=10)
for song, score in similar:
    print(f"{song}: {score:.4f}")
# Out:
# pink floyd__comfortably numb: 0.8690
# pink floyd__hey you: 0.8272
# pink floyd__time: 0.7797
# pink floyd__money: 0.7578
# pink floyd__us and them: 0.7558
# led zeppelin__stairway to heaven: 0.7466
# pink floyd__high hopes: 0.7439
# pink floyd__the great gig in the sky: 0.7374
# pink floyd__shine on you crazy diamond: 0.7184
# pink floyd__welcome to the machine: 0.7057

# %%
similar = final_model.wv.most_similar("nirvana__smells like teen spirit", topn=10)
for song, score in similar:
    print(f"{song}: {score:.4f}")
# Out:
# nirvana__come as you are: 0.8906
# nirvana__lithium: 0.8588
# nirvana__rape me: 0.8286
# nirvana__in bloom: 0.7922
# nirvana__polly: 0.7451
# nirvana__about a girl: 0.7361
# nirvana__all apologies: 0.7234
# nirvana__drain you: 0.7071
# nirvana__breed: 0.6947
# nirvana__dumb: 0.6946

# %%
final_model.wv.most_similar(
    positive=["queen__bohemian rhapsody", "led zeppelin__stairway to heaven"],
    negative=["nirvana__smells like teen spirit"]
)
# Out:
# [('led zeppelin__kashmir', 0.6514701247215271),
#  ('pink floyd__wish you were here', 0.6090667843818665),
#  ('led zeppelin__whole lotta love', 0.6061370968818665),
#  ("led zeppelin__since i've been loving you", 0.5956087112426758),
#  ('led zeppelin__immigrant song', 0.5918290019035339),
#  ('lynyrd skynyrd__sweet home alabama', 0.585025429725647),
#  ('led zeppelin__black dog', 0.5761316418647766),
#  ('deep purple__smoke on the water', 0.5733107924461365),
#  ('jethro tull__aqualung', 0.5726091265678406),
#  ('deep purple__child in time', 0.5670084953308105)]

# %%
final_model.wv.most_similar(
    positive=["pink floyd__wish you were here", "led zeppelin__stairway to heaven"],
    negative=["michael jackson__thriller"]
)
# Out:
# [('pink floyd__comfortably numb', 0.6936275959014893),
#  ('pink floyd__hey you', 0.6448172926902771),
#  ('led zeppelin__kashmir', 0.6341468095779419),
#  ('led zeppelin__whole lotta love', 0.6334332227706909),
#  ("led zeppelin__since i've been loving you", 0.6287224888801575),
#  ('deep purple__child in time', 0.6176342964172363),
#  ('led zeppelin__the battle of evermore', 0.6154232025146484),
#  ('pink floyd__the great gig in the sky', 0.614818811416626),
#  ('pink floyd__time', 0.6062097549438477),
#  ('led zeppelin__immigrant song', 0.6041151285171509)]

# %%
final_model.wv.most_similar(
    positive=["queen__bohemian rhapsody", "michael jackson__thriller"],
    negative=["pink floyd__wish you were here"]
)
# Out:
# [('michael jackson__bad', 0.7450981736183167),
#  ('michael jackson__beat it', 0.7007122039794922),
#  ('michael jackson__man in the mirror', 0.6976467967033386),
#  ('michael jackson__billie jean', 0.6828221082687378),
#  ('michael jackson__black or white', 0.6827552318572998),
#  ('michael jackson__rock with you', 0.6709281802177429),
#  ('michael jackson__smooth criminal', 0.6689131855964661),
#  ('michael jackson__the way you make me feel', 0.662318766117096),
#  ("michael jackson__wanna be startin' somethin'", 0.6316487193107605),
#  ('michael jackson__you are not alone', 0.597048282623291)]

# %%
songs = []
vectors = []

for song, count in counterDict.most_common(500):
    if song in final_model.wv:
        songs.append(song)
        vectors.append(final_model.wv[song])

vectors = np.array(vectors)
print(vectors.shape)
# Out:
# (500, 100)

# %%
tsne = TSNE(n_components=2, random_state=42)
vectors_2d = tsne.fit_transform(vectors)

# %%
artists = [song.split("__")[0] for song in songs]

top_artists = [artist for artist, _ in Counter(artists).most_common(10)]

colors = []
for artist in artists:
    if artist in top_artists:
        colors.append(top_artists.index(artist))
    else:
        colors.append(-1)

plt.figure(figsize=(14, 10))
scatter = plt.scatter(vectors_2d[:, 0], vectors_2d[:, 1], 
                      c=colors, cmap='tab10', alpha=0.7, s=20)

for i, song in enumerate(songs[:50]):
    plt.annotate(song.split("__")[1], (vectors_2d[i, 0], vectors_2d[i, 1]), fontsize=6)

# Legend
for i, artist in enumerate(top_artists):
    plt.scatter([], [], c=[plt.cm.tab10(i/10)], label=artist)
plt.legend(loc='upper right', fontsize=8)

plt.title("Song Embeddings t-SNE (colored by artist)")
plt.xlabel("t-SNE 1")
plt.ylabel("t-SNE 2")
plt.tight_layout()
plt.show()

# %%
def RecommendSong(seed_songs, model, top_k=10):
    total_embedding = 0
    count = 0
    for song in seed_songs:
        if song in model.wv:
            total_embedding += model.wv[song]
            count += 1
    if count == 0:
        return []
    avg_embedding = total_embedding / count
    recommendations = model.wv.most_similar(positive=[avg_embedding], topn=top_k + len(seed_songs))
    rawRecommendations = [song for song, score in recommendations if song not in seed_songs]
    return rawRecommendations

seeds = ["queen__bohemian rhapsody", "led zeppelin__stairway to heaven"]
RecommendSong(seeds, final_model, top_k=10)
# Out:
# ['deep purple__smoke on the water',
#  'led zeppelin__whole lotta love',
#  'queen__we will rock you',
#  'led zeppelin__kashmir',
#  'led zeppelin__immigrant song',
#  'pink floyd__wish you were here',
#  'eagles__hotel california',
#  'the rolling stones__paint it black',
#  'black sabbath__paranoid',
#  'led zeppelin__black dog']

# %%
total_unique = len(counterDict)
vocab = set(final_model.wv.key_to_index.keys())
oov_total = sum(1 for track in counterDict if track not in vocab)
oov_percent = oov_total / total_unique * 100
print(f"Total unique tracks: {total_unique}")
print(f"OOV tracks: {oov_total} ({oov_percent:.2f}%)")

test_tracks = set(track for playlist in test_data for track in playlist)
oov_test = sum(1 for track in test_tracks if track not in vocab)
oov_test_percent = oov_test / len(test_tracks) * 100
print(f"Test set unique tracks: {len(test_tracks)}")
print(f"OOV in test set: {oov_test} ({oov_test_percent:.2f}%)")
# Out:
# Total unique tracks: 391991
# OOV tracks: 370631 (94.55%)
# Test set unique tracks: 164431
# OOV in test set: 144174 (87.68%)

# %%
artist_embeddings = {}
for song in vocab:
    artist = song.split("__")[0]
    if artist not in artist_embeddings:
        artist_embeddings[artist] = []
    artist_embeddings[artist].append(final_model.wv[song])

artist_avg_embeddings = {}
for artist, embeddings in artist_embeddings.items():
    artist_avg_embeddings[artist] = np.mean(embeddings, axis=0)

def get_embedding_with_fallback(song, model):
    if song in model.wv:
        return model.wv[song]
    artist = song.split("__")[0]
    if artist in artist_avg_embeddings:
        return artist_avg_embeddings[artist]
    return None

# %%
def SingleQuerySongFiltered(model, min_count=None, max_count=None, k=10):
    total_score = 0
    total_trial = 0
    total_ndcg = 0
    for sentence in test_data:
        if len(sentence) < 2:
            continue
        lastSong = sentence[-1]
        secondLastSong = sentence[-2]
        if lastSong not in model.wv or secondLastSong not in model.wv:
            continue
        count = counterDict.get(lastSong, 0)
        if min_count and count < min_count:
            continue
        if max_count and count > max_count:
            continue
        embedding = model.wv[secondLastSong]
        predictionList = model.wv.most_similar(positive=[embedding], topn=k)
        songList = [song for song, score in predictionList]
        if lastSong in songList:
            total_score += 1
            rank = songList.index(lastSong) + 1
            total_ndcg += 1 / math.log2(rank + 1)
        total_trial += 1
    if total_trial == 0:
        return 0, 0
    return total_score / total_trial, total_ndcg / total_trial

hr_popular, ndcg_popular = SingleQuerySongFiltered(final_model, min_count=100)
hr_rare, ndcg_rare = SingleQuerySongFiltered(final_model, max_count=10)
print(f"Popular songs (>100): HR@10={hr_popular:.4f}, NDCG@10={ndcg_popular:.4f}")
print(f"Rare songs (<10): HR@10={hr_rare:.4f}, NDCG@10={ndcg_rare:.4f}")
# Out:
# Popular songs (>100): HR@10=0.2395, NDCG@10=0.1619
# Rare songs (<10): HR@10=0.0175, NDCG@10=0.0111

# %%
def HR_by_playlist_length(model, k=10):
    short = {"score": 0, "trial": 0}
    medium = {"score": 0, "trial": 0}
    long = {"score": 0, "trial": 0}
    
    for sentence in test_data:
        if len(sentence) < 2:
            continue
        lastSong = sentence[-1]
        secondLastSong = sentence[-2]
        if lastSong not in model.wv or secondLastSong not in model.wv:
            continue
        
        if len(sentence) < 10:
            group = short
        elif len(sentence) <= 30:
            group = medium
        else:
            group = long
            
        embedding = model.wv[secondLastSong]
        predictionList = model.wv.most_similar(positive=[embedding], topn=k)
        songList = [song for song, score in predictionList]
        
        if lastSong in songList:
            group["score"] += 1
        group["trial"] += 1
    
    for name, group in [("Short (<10)", short), ("Medium (10-30)", medium), ("Long (>30)", long)]:
        if group["trial"] > 0:
            print(f"{name}: HR@10={group['score']/group['trial']:.4f}, n={group['trial']}")

HR_by_playlist_length(final_model)
# Out:
# Short (<10): HR@10=0.1262, n=618
# Medium (10-30): HR@10=0.1304, n=621
# Long (>30): HR@10=0.1347, n=542
